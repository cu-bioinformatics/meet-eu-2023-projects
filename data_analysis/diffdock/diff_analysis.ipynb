# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy.stats import spearmanr

# %%
diff = pd.read_csv('/Users/faflik/Projects/MoleculeScreen/Data/results/diffdock/Diffdock_results.csv')
vina = pd.read_csv('/Users/faflik/Projects/MoleculeScreen/Data/results/repurposing/7RDY/updated_repurposing_result.csv')

# %%
diff.head()
# Out:
#    Index      PDB Code                          SMILES Chemical Structure  \
# 0      0  tmp-pdb-7RDY  NC1=NC=NC2=C1N=CN2[C@@H]1O[C@@H]2CO[P@](S)(=O)...
# 1      1  tmp-pdb-7RDY  [H][C@@]12CC[C@]3(C)[C@]([H])(CCC4=C5CC(C)(C)C...
# 2      2  tmp-pdb-7RDY  [H][C@@]1(CC[C@]2(O)[C@]3([H])CCC4=C[C@]([H])(...
# 3      3  tmp-pdb-7RDY  CC1(C)CCC2(CC1)N[C@H]([C@H](C1=C(F)C(Cl)=NC=C1...
# 4      4  tmp-pdb-7RDY  [H][C@@]12CC3=CC(OC4=CC=C(C[C@]5([H])N(C)CCC6=...
#
#        Best      Mean   Run times  Min self distances
# 0 -1.257020 -2.463142  226.951520            1.323899
# 1 -1.452247 -3.132486  170.946050            1.298984
# 2 -1.473806 -2.746019  193.545979            1.257796
# 3 -1.515139 -3.046909  201.739631            1.255977
# 4 -1.330953 -3.106141  204.903096            1.347190

# %%
diff['Best'][29]
# Out:
# -1.1251326

# %%
diff['Index'][29]
# Out:
# 38

# %%
vina.head()
# Out:
#        proteinID              ligandID       mean  median   max   min  \
# 0  7RDY-no-extra  Mrv1909-10091921542D -17.747059  -17.70 -17.7 -17.9
# 1  7RDY-no-extra  Mrv0541-02231214492D -15.847727  -15.85 -15.5 -16.1
# 2      7RDY-zinc  Mrv1909-08181923252D -15.500000  -15.50 -15.5 -15.5
# 3  7RDY-no-extra  Mrv0541-02231215192D -14.802273  -14.70 -14.7 -15.0
# 4  7RDY-no-extra  Mrv0541-02231215202D -14.772727  -14.75 -14.6 -14.9
#
#         var DATABASE_ID DATABASE_NAME  \
# 0  0.003897     DB15532      drugbank
# 1  0.065344     DB00615      drugbank
# 2  0.000000     DB01152      drugbank
# 3  0.013716     DB01201      drugbank
# 4  0.013192     DB01220      drugbank
#
#                                               SMILES  ... DRUGBANK_ID  \
# 0  [H][C@@]1(O[C@@H]2[C@@H](CO)O[C@@H](OC[C@H]3O[...  ...     DB15532
# 1  CO[C@H]1\C=C\O[C@@]2(C)OC3=C(C2=O)C2=C(C(O)=C3...  ...     DB00615
# 2  CC(CC(C)C1OC(=O)CC(=O)CCCC(=O)CC(O)CC(O)CC(O)C...  ...     DB01152
# 3  CO[C@H]1\C=C\O[C@@]2(C)OC3=C(C2=O)C2=C(C(O)=C3...  ...     DB01201
# 4  CO[C@H]1\C=C\O[C@@]2(C)OC3=C(C)C(O)=C4C(O)=C(N...  ...     DB01220
#
#                  DRUG_GROUPS   GENERIC_NAME  \
# 0               experimental  Madecassoside
# 1  approved; investigational      Rifabutin
# 2        approved; withdrawn     Candicidin
# 3  approved; investigational    Rifapentine
# 4  approved; investigational      Rifaximin
#
#                                             SYNONYMS  \
# 0                           Asiaticoside A; Redermic
# 1  1,4-Dihydro-1-deoxy-1',4-didehydro-5'-(2-methy...
# 2  Candicidin; Candicidina; Candicidine; Candicid...
# 3  3-(((4-Cyclopentyl-1-piperazinyl)imino)methyl)...
# 4  Rifamycin L 105; Rifamycin L 105SV; Rifaxidin;...
#
#                                             PRODUCTS  \
# 0  CareMe Madecassoside Cica Derma Repair Control...
# 1                      Mycobutin; Rifabutin; Talicia
# 2                                                NaN
# 3                                            Priftin
# 4                                    Xifaxan; Zaxine
#
#    JCHEM_AVERAGE_NEUTRAL_MICROSPECIES_CHARGE  JCHEM_NEUTRAL_CHARGE  \
# 0                                        NaN                     n
# 1                                   0.454171                     0
# 2                                        NaN                     n
# 3                                   0.287753                     0
# 4                                  -1.007268                    -1
#
#    SECONDARY_ACCESSION_NUMBERS            INTERNATIONAL_BRANDS  \
# 0                          NaN                             NaN
# 1                    APRD00094  Ansatipin; Ansatipine; Ributin
# 2                    APRD00843                         Vanobid
# 3                    APRD01217                             NaN
# 4                    APRD01218       Normix; Rifacol; Xifaxsan
#
#                        SALTS
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3  Rifapentine hydrochloride
# 4                        NaN
#
# [5 rows x 49 columns]

# %%
def filter_dataframe(df_to_filter, df_reference, column_to_filter, reference_column):
    """
    Drops rows from df_to_filter whose values in column_to_filter are not found in reference_column of df_reference.

    Parameters:
    df_to_filter (pd.DataFrame): DataFrame to be filtered.
    df_reference (pd.DataFrame): DataFrame to use as reference for filtering.
    column_to_filter (str): Column name in df_to_filter to apply the filter on.
    reference_column (str): Column name in df_reference to compare against.

    Returns:
    pd.DataFrame: Filtered DataFrame.
    """
    # Identify values in the reference column
    reference_values = set(df_reference[reference_column])

    # Filter the DataFrame
    filtered_df = df_to_filter[df_to_filter[column_to_filter].isin(reference_values)]

    return filtered_df

# %%
vina = filter_dataframe(vina, diff, 'SMILES', 'SMILES Chemical Structure')

# %%
vina.count()
# Out:
# proteinID                                    55
# ligandID                                     55
# mean                                         55
# median                                       55
# max                                          55
# min                                          55
# var                                          55
# DATABASE_ID                                  55
# DATABASE_NAME                                55
# SMILES                                       55
# INCHI_IDENTIFIER                             55
# INCHI_KEY                                    55
# FORMULA                                      55
# MOLECULAR_WEIGHT                             55
# EXACT_MASS                                   55
# JCHEM_ACCEPTOR_COUNT                         55
# JCHEM_ATOM_COUNT                             55
# JCHEM_AVERAGE_POLARIZABILITY                 55
# JCHEM_BIOAVAILABILITY                        55
# JCHEM_DONOR_COUNT                            55
# JCHEM_FORMAL_CHARGE                          55
# JCHEM_GHOSE_FILTER                           55
# JCHEM_IUPAC                                  55
# ALOGPS_LOGP                                  54
# JCHEM_LOGP                                   55
# ALOGPS_LOGS                                  54
# JCHEM_MDDR_LIKE_RULE                         55
# JCHEM_NUMBER_OF_RINGS                        55
# JCHEM_PHYSIOLOGICAL_CHARGE                   55
# JCHEM_PKA                                    40
# JCHEM_PKA_STRONGEST_ACIDIC                   53
# JCHEM_PKA_STRONGEST_BASIC                    55
# JCHEM_POLAR_SURFACE_AREA                     55
# JCHEM_REFRACTIVITY                           55
# JCHEM_ROTATABLE_BOND_COUNT                   55
# JCHEM_RULE_OF_FIVE                           55
# ALOGPS_SOLUBILITY                            54
# JCHEM_TRADITIONAL_IUPAC                      55
# JCHEM_VEBER_RULE                             55
# DRUGBANK_ID                                  55
# DRUG_GROUPS                                  55
# GENERIC_NAME                                 55
# SYNONYMS                                     41
# PRODUCTS                                     13
# JCHEM_AVERAGE_NEUTRAL_MICROSPECIES_CHARGE    29
# JCHEM_NEUTRAL_CHARGE                         55
# SECONDARY_ACCESSION_NUMBERS                  15
# INTERNATIONAL_BRANDS                         10
# SALTS                                        13
# dtype: int64

# %%
diff['Diff_Rank_Best'] = diff['Best'].rank(method='first')
diff['Diff_Rank_Mean'] = diff['Mean'].rank(method='first')
vina['Vina_Rank'] = vina['mean'].rank(method='first')

# %%
merged = pd.merge(diff, vina, left_on='SMILES Chemical Structure', right_on='SMILES')

# %%
merged.count()
# Out:
# Index                                        55
# PDB Code                                     55
# SMILES Chemical Structure                    55
# Best                                         55
# Mean                                         55
# Run times                                    55
# Min self distances                           55
# Diff_Rank_Best                               55
# Diff_Rank_Mean                               55
# proteinID                                    55
# ligandID                                     55
# mean                                         55
# median                                       55
# max                                          55
# min                                          55
# var                                          55
# DATABASE_ID                                  55
# DATABASE_NAME                                55
# SMILES                                       55
# INCHI_IDENTIFIER                             55
# INCHI_KEY                                    55
# FORMULA                                      55
# MOLECULAR_WEIGHT                             55
# EXACT_MASS                                   55
# JCHEM_ACCEPTOR_COUNT                         55
# JCHEM_ATOM_COUNT                             55
# JCHEM_AVERAGE_POLARIZABILITY                 55
# JCHEM_BIOAVAILABILITY                        55
# JCHEM_DONOR_COUNT                            55
# JCHEM_FORMAL_CHARGE                          55
# JCHEM_GHOSE_FILTER                           55
# JCHEM_IUPAC                                  55
# ALOGPS_LOGP                                  54
# JCHEM_LOGP                                   55
# ALOGPS_LOGS                                  54
# JCHEM_MDDR_LIKE_RULE                         55
# JCHEM_NUMBER_OF_RINGS                        55
# JCHEM_PHYSIOLOGICAL_CHARGE                   55
# JCHEM_PKA                                    40
# JCHEM_PKA_STRONGEST_ACIDIC                   53
# JCHEM_PKA_STRONGEST_BASIC                    55
# JCHEM_POLAR_SURFACE_AREA                     55
# JCHEM_REFRACTIVITY                           55
# JCHEM_ROTATABLE_BOND_COUNT                   55
# JCHEM_RULE_OF_FIVE                           55
# ALOGPS_SOLUBILITY                            54
# JCHEM_TRADITIONAL_IUPAC                      55
# JCHEM_VEBER_RULE                             55
# DRUGBANK_ID                                  55
# DRUG_GROUPS                                  55
# GENERIC_NAME                                 55
# SYNONYMS                                     41
# PRODUCTS                                     13
# JCHEM_AVERAGE_NEUTRAL_MICROSPECIES_CHARGE    29
# JCHEM_NEUTRAL_CHARGE                         55
# SECONDARY_ACCESSION_NUMBERS                  15
# INTERNATIONAL_BRANDS                         10
# SALTS                                        13
# Vina_Rank                                    55
# dtype: int64

# %%
merged['Ranking_Difference_vina/best'] = abs(merged['Diff_Rank_Best'] - merged['Vina_Rank'])
merged['Ranking_Difference_vina/mean'] = abs(merged['Diff_Rank_Mean'] - merged['Vina_Rank'])

# %%
def hist(merged_df, col, title='Ranking Difference'):
    # Histogram/Boxplot for Ranking Differences
    plt.figure(figsize=(10, 6))
    sns.histplot(merged_df[col], bins=40, kde=True, color='blue', edgecolor='black', alpha=0.7)
    plt.title(title)
    plt.xlabel(title)
    plt.ylabel('Frequency')
    plt.show()

# %%
hist(merged, 'Ranking_Difference_vina/best', title='Ranking Difference vina/diffdock best')
# Out:
# /Users/faflik/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
hist(merged, 'Ranking_Difference_vina/mean', title='Ranking Difference vina/diffdock mean')
# Out:
# /Users/faflik/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
merged['Ranking_Difference_vina/best'].describe()
# Out:
# count    55.000000
# mean     16.872727
# std      13.430279
# min       0.000000
# 25%       5.500000
# 50%      14.000000
# 75%      24.000000
# max      46.000000
# Name: Ranking_Difference_vina/best, dtype: float64

# %%
merged['Ranking_Difference_vina/mean'].describe()
# Out:
# count    55.000000
# mean     18.109091
# std      12.908040
# min       0.000000
# 25%       7.500000
# 50%      17.000000
# 75%      24.000000
# max      54.000000
# Name: Ranking_Difference_vina/mean, dtype: float64

# %%
def Scatter(merged_df, x, y='Vina_Rank'):
    # Scatter Plot
    plt.figure(figsize=(10, 6))
    sns.scatterplot(x=x, y=y, data=merged_df)
    plt.title('Comparison of Drug Docking Approaches')
    plt.xlabel('Diffdock Score (Approach 1)')
    plt.ylabel('Vina Score (Approach 2)')
    plt.show()

# %%
Scatter(merged, 'Diff_Rank_Best')

# %%
Scatter(merged, 'Diff_Rank_Mean')

# %%
def correlation(merged_df, col):
    # Calculate Spearman's rank correlation
    correlation, p_value = spearmanr(merged_df[col], merged_df['Vina_Rank'])
    
    print(f"Spearman's rank correlation coefficient: {correlation:.3f}")
    print(f"P-value: {p_value:.3f}")

# Interpret the results
# A correlation close to 1 indicates a strong positive relationship,
# close to -1 indicates a strong negative relationship,
# and around 0 indicates no relationship.

# %%
correlation(merged, 'Diff_Rank_Best')
# Out:
# Spearman's rank correlation coefficient: 0.084
# P-value: 0.543

# %%
correlation(merged, 'Diff_Rank_Mean')
# Out:
# Spearman's rank correlation coefficient: 0.025
# P-value: 0.858

# %%
merged
# Out:
#     Index      PDB Code                          SMILES Chemical Structure  \
# 0       0  tmp-pdb-7RDY  NC1=NC=NC2=C1N=CN2[C@@H]1O[C@@H]2CO[P@](S)(=O)...
# 1       1  tmp-pdb-7RDY  [H][C@@]12CC[C@]3(C)[C@]([H])(CCC4=C5CC(C)(C)C...
# 2       2  tmp-pdb-7RDY  [H][C@@]1(CC[C@]2(O)[C@]3([H])CCC4=C[C@]([H])(...
# 3       3  tmp-pdb-7RDY  CC1(C)CCC2(CC1)N[C@H]([C@H](C1=C(F)C(Cl)=NC=C1...
# 4       4  tmp-pdb-7RDY  [H][C@@]12CC3=CC(OC4=CC=C(C[C@]5([H])N(C)CCC6=...
# 5       6  tmp-pdb-7RDY  [H][C@]12CC=C3[C@]4([H])[C@@H](C)[C@H](C)CC[C@...
# 6       7  tmp-pdb-7RDY  [H][C@@]12CC3=CC=C(OC4=C5C(CC[N+](C)(C)[C@]5([...
# 52 -1.940627 -3.268211  203.364934            1.255352            14.0
# 53 -1.960778 -3.116601  197.568964            1.257166            12.0
# 54 -1.203298 -2.604081  195.105153            1.245298            49.0
#
#     Diff_Rank_Mean      proteinID  ...  \
# 0             55.0  7RDY-no-extra  ...
# 1             26.0  7RDY-no-extra  ...
# 2             48.0  7RDY-no-extra  ...
# 3             37.0      7RDY-zinc  ...
# 4             29.0      7RDY-zinc  ...
# 5             21.0  7RDY-no-extra  ...
# 6             27.0      7RDY-zinc  ...
# 7             19.0  7RDY-no-extra  ...
# 8             30.0      7RDY-zinc  ...
# 9              6.0  7RDY-no-extra  ...
# 10            17.0  7RDY-no-extra  ...
# 11             8.0      7RDY-zinc  ...
# 12            33.0  7RDY-no-extra  ...
# 13            54.0  7RDY-no-extra  ...
# 14             4.0      7RDY-zinc  ...
# 15             7.0      7RDY-zinc  ...
# 16            41.0      7RDY-zinc  ...
# 17            42.0      7RDY-zinc  ...
# 18            35.0      7RDY-zinc  ...
# 19            46.0      7RDY-zinc  ...
# 20            14.0  7RDY-no-extra  ...
# 21            39.0  7RDY-no-extra  ...
# 22             5.0  7RDY-no-extra  ...
# 23            15.0      7RDY-zinc  ...
# 24            11.0  7RDY-no-extra  ...
# 25            25.0      7RDY-zinc  ...
# 26             1.0  7RDY-no-extra  ...
# 27            18.0  7RDY-no-extra  ...
# 28            36.0  7RDY-no-extra  ...
# 29            10.0      7RDY-zinc  ...
# 30            32.0      7RDY-zinc  ...
# 31            43.0      7RDY-zinc  ...
# 32            13.0  7RDY-no-extra  ...
# 33            50.0      7RDY-zinc  ...
# 34            40.0  7RDY-no-extra  ...
# 35            52.0      7RDY-zinc  ...
# 36            47.0      7RDY-zinc  ...
# 37             9.0      7RDY-zinc  ...
# 38            34.0      7RDY-zinc  ...
# 39            23.0  7RDY-no-extra  ...
# 40            24.0      7RDY-zinc  ...
# 41            22.0  7RDY-no-extra  ...
# 42            49.0  7RDY-no-extra  ...
# 43            44.0  7RDY-no-extra  ...
# 44            51.0      7RDY-zinc  ...
# 45            38.0      7RDY-zinc  ...
# 46             2.0  7RDY-no-extra  ...
# 47            31.0  7RDY-no-extra  ...
# 48             3.0  7RDY-no-extra  ...
# 49            16.0  7RDY-no-extra  ...
# 50            45.0      7RDY-zinc  ...
# 51            20.0  7RDY-no-extra  ...
# 52            12.0  7RDY-no-extra  ...
# 53            28.0      7RDY-zinc  ...
# 54            53.0      7RDY-zinc  ...
#
#                                              SYNONYMS  \
# 0                                  ADU-S100 free acid
# 1                                           Coflodiol
# 2                                      Proscillaridin
# 3                                         Milademetan
# 4                         Cepharanthin; Cepharanthine
# 5                6β-hydroxyasiatic acid; Brahmic acid
# 6   (+)-tubocurarine; 7',12'-dihydroxy-6,6'-dimeth...
# 7                                           Bizelesin
# 8                                                 NaN
# 9                                           Steviosin
# 10                               Malol; Prunol; Urson
# 11  3-(aminocarbonyl)-O4-deacetyl-3-de(methoxycarb...
# 12                                                NaN
# 13                                         Vilaprisan
# 14  Acetildigitoxina; Acetyl-digitoxin-alpha; Acet...
# 15                                                NaN
# 16  (9.beta.,13.alpha.,14.beta.,20.alpha.)-3-hydro...
# 17                                        Bardoxolone
# 18                                      Lurbinectedin
# 19                                                NaN
# 20                                                NaN
# 21       Ecteinascidin 743; Trabectedin; Trabectedina
# 22                                                NaN
# 23             Hsp90-targeted sn-38 conjugate pen-866
# 24                     Flurithromycin; fluritromicina
# 25  (1'-methyl-6,7-dihydro-5h-spiro(furo(2,3-f)ind...
# 26  3,3'-{[(4R,5S,6S,7R)-4,7-Dibenzyl-5,6-dihydrox...
# 27                                                NaN
# 28                                                NaN
# 29                                          Tirilazad
# 30                                    Dammarolic acid
# 31                               Patidegib; Saridegib
# 32                                                NaN
# 33  (3.beta.,5.beta.,25s)-spirostan-3-ol; Myogane;...
# 34                                                NaN
# 35                                                NaN
# 36                                         Sagopilone
# 37             4'-N-benzoylstaurosporine; Midostaurin
# 38               Vaniprévir; Vaniprevir; Vaniprevirum
# 39  (5α,17β)-N-(2,5-bis(trifluoromethyl)phenyl)-3-...
# 40  22-Oxovincaleukoblastin; 22-Oxovincaleukoblast...
# 41  Benzoic acid hydrazide, 3-hydrazone with dauno...
# 42  Algeston acetofenid; Algestone acetophenide; A...
# 43                                        Vistusertib
# 44                                                NaN
# 45             Betuline; Betulinic alcohol; Betulinol
# 46  20',20'-difluoro-3',4'-dihydrovinorelbine; 4'-...
# 47                                                NaN
# 48             Azalomycin M; Helixin C; Polyetherin A
# 49                       Carbenoxolona; Carbenoxolone
# 50                                                NaN
# 51  Azithromycin; Azithromycine; Azithromycinum; A...
# 52  (2R,4R,7R)-N-[(1S,2S,4R,7S)-7-benzyl-2-hydroxy...
# 53                                         Tropifexor
# 54          Eravacyclina; Eravacycline; Eravacyclinum
#
#                                              PRODUCTS  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   Callicos CellAwake Mask madecassol; Centella S...
# 6   Tubocurarine Chloride Inj 3mg/ml; Tubocurarine...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                               Eldisine Inj 5mg/2ml
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                           Zepzelca
# 19                                                NaN
# 20                                                NaN
# 21                                           Yondelis
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30  Centella Scar Ylang Ylang; Karatica Im Cica Es...
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                             Rydapt
# 38                                                NaN
# 39  Act Dutasteride; Ag-dutasteride; Apo-dutasteri...
# 40  Marqibo; Oncovin Solution 1mg/ml; VinCRIStine ...
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                             Javlor
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51  Act Azithromycin; Ag-azithromycin; Apo-azithro...
# 52  D.H.E. 45; Dihydroergotamine (dhe), 1mg/ml; Di...
# 53                                                NaN
# 54                                             Xerava
#
#     JCHEM_AVERAGE_NEUTRAL_MICROSPECIES_CHARGE  JCHEM_NEUTRAL_CHARGE  \
# 0                               -1.979540e+00                    -2
# 1                                         NaN                     n
# 2                                         NaN                     n
# 3                                         NaN                     n
# 4                                1.700946e+00                     2
# 5                                         NaN                     n
# 6                                1.852538e+00                     2
# 7                                         NaN                     n
# 8                                         NaN                     n
# 9                               -2.591761e-05                     0
# 10                                        NaN                     n
# 11                               1.886271e+00                     2
# 12                                        NaN                     n
# 13                                        NaN                     n
# 14                              -3.963899e-01                     0
# 15                                        NaN                     n
# 16                              -1.764605e-03                     0
# 17                                        NaN                     n
# 18                               2.125057e+00                     1
# 19                              -3.998385e-08                     0
# 20                                        NaN                     n
# 21                               6.095679e-01                     1
# 22                               1.849279e+00                     2
# 23                              -3.458747e-02                     0
# 24                                        NaN                     n
# 25                               9.851606e-01                     1
# 26                                        NaN                     n
# 27                               1.945145e+00                     2
# 28                                        NaN                     n
# 29                                        NaN                     n
# 30                                        NaN                     n
# 31                                        NaN                     n
# 32                              -3.000225e+00                    -3
# 33                               4.400930e-09                     0
# 34                                        NaN                     n
# 35                               2.016010e-04                     0
# 36                                        NaN                     n
# 37                                        NaN                     n
# 38                              -9.994220e-01                    -1
# 39                              -2.716994e-06                     0
# 40                               1.891972e+00                     2
# 41                               9.362815e-01                     1
# 42                              -1.488361e-11                     0
# 43                                        NaN                     n
# 44                                        NaN                     n
# 45                               1.964783e-08                     0
# 46                                        NaN                     n
# 47                                        NaN                     n
# 48                                        NaN                     n
# 49                              -1.994331e+00                    -2
# 50                               3.847089e-08                     0
# 51                               1.985157e+00                     2
# 52                               1.000524e+00                     1
# 53                              -9.996232e-01                    -1
# 54                              -6.218827e-01                    -1
#
#     SECONDARY_ACCESSION_NUMBERS  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6                     APRD00176
# 7                           NaN
# 8                           NaN
# 9                           NaN
# 10                          NaN
# 11                    APRD00392
# 12                          NaN
# 13                          NaN
# 14                    APRD01334
# 15                          NaN
# 16                          NaN
# 17                      DB06120
# 18                          NaN
# 19                          NaN
# 20                          NaN
# 21                          NaN
# 22                    EXPT02805
# 23                          NaN
# 24                          NaN
# 25                          NaN
# 26                    EXPT00032
# 27                    EXPT01963
# 28                          NaN
# 29                          NaN
# 30                          NaN
# 31                      DB05922
# 32                    EXPT00841
# 33                          NaN
# 34                          NaN
# 35                          NaN
# 36                      DB05654
# 37                          NaN
# 38                          NaN
# 39                    APRD00385
# 40                    APRD00495
# 41                          NaN
# 42                          NaN
# 43                          NaN
# 44                          NaN
# 45                          NaN
# 46                          NaN
# 47                          NaN
# 48                          NaN
# 49                    EXPT00848
# 50                          NaN
# 51                    APRD00397
# 52           APRD00476; DB05743
# 53                          NaN
# 54                          NaN
#
#                                  INTERNATIONAL_BRANDS  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                            Tubarine
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                 Eldesine; Eldisine
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                            Zepsyre
# 19                                        Ruscorectal
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                            Vanihep
# 39                                                NaN
# 40  Alcavixin; Alcrist; Citomid; Cytocristin; Onco...
# 41                                                NaN
# 42                        Bovitrol; Droxone; Neolutin
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49  Carbelone; Carbosan; Carboxe; Copu; Herpesan; ...
# 50                                                NaN
# 51  Azenil; Azibiot; Azifast; Azigram; Azimakrol; ...
# 52  Dihydergot; Ergont; Ergotonin; Ikaran; Orstano...
# 53                                                NaN
# 54                                                NaN
#
#                                                 SALTS Vina_Rank  \
# 0                                     ADU-S100 sodium       1.0
# 1                                                 NaN       2.0
# 2                                                 NaN       3.0
# 3                                                 NaN       4.0
# 4                                                 NaN       5.0
# 5                                                 NaN       6.0
# 6                  Tubocurarine chloride pentahydrate       7.0
# 7                                                 NaN       8.0
# 8                                                 NaN       9.0
# 9                                                 NaN      10.0
# 10                                                NaN      11.0
# 11                                  Vindesine sulfate      12.0
# 12                                                NaN      13.0
# 13                                                NaN      14.0
# 14                                                NaN      15.0
# 15                                                NaN      16.0
# 16                                                NaN      17.0
# 17                                                NaN      18.0
# 18                                                NaN      19.0
# 19                                                NaN      20.0
# 20                                                NaN      21.0
# 21                                                NaN      22.0
# 22                                                NaN      23.0
# 23                                                NaN      24.0
# 24                                                NaN      25.0
# 25                            SB 224289 hydrochloride      26.0
# 26                                                NaN      27.0
# 27                                                NaN      28.0
# 28                                                NaN      29.0
# 29                                                NaN      30.0
# 30                                                NaN      31.0
# 31                                                NaN      32.0
# 32                                                NaN      33.0
# 33                                                NaN      34.0
# 34                                                NaN      35.0
# 35                                                NaN      36.0
# 36                                                NaN      37.0
# 37                                                NaN      38.0
# 38                               Vaniprevir potassium      39.0
# 39                                                NaN      40.0
# 40                                Vincristine sulfate      41.0
# 41                            Zorubicin hydrochloride      42.0
# 42                                                NaN      43.0
# 43                                                NaN      44.0
# 44                                                NaN      45.0
# 45                                                NaN      46.0
# 46                              Vinflunine ditartrate      47.0
# 47                                                NaN      48.0
# 48                                   Nigericin sodium      49.0
# 49                             Carbenoxolone disodium      50.0
# 50                                                NaN      51.0
# 51  Azithromycin dihydrate; Azithromycin hemiethan...      52.0
# 52  Dihydroergotamine mesylate; Dihydroergotamine ...      53.0
# 53                                                NaN      54.0
# 54                       Eravacycline dihydrochloride      55.0
#
#    Ranking_Difference_vina/best Ranking_Difference_vina/mean
# 0                          46.0                         54.0
# 1                          34.0                         24.0
# 2                          31.0                         45.0
# 3                          26.0                         33.0
# 4                          38.0                         24.0
# 5                           5.0                         15.0
# 6                          10.0                         20.0
# 7                          10.0                         11.0
# 8                          26.0                         21.0
# 9                           2.0                          4.0
# 10                         16.0                          6.0
# 11                          5.0                          4.0
# 12                         20.0                         20.0
# 13                         41.0                         40.0
# 14                         14.0                         11.0
# 15                          6.0                          9.0
# 16                         31.0                         24.0
# 17                         27.0                         24.0
# 18                          3.0                         16.0
# 19                         20.0                         26.0
# 20                          2.0                          7.0
# 21                          0.0                         17.0
# 22                         21.0                         18.0
# 23                         15.0                          9.0
# 24                         19.0                         14.0
# 25                          2.0                          1.0
# 26                         22.0                         26.0
# 27                          3.0                         10.0
# 28                         14.0                          7.0
# 29                         21.0                         20.0
# 30                          5.0                          1.0
# 31                          0.0                         11.0
# 32                         10.0                         20.0
# 33                         20.0                         16.0
# 34                         14.0                          5.0
# 35                         17.0                         16.0
# 36                          4.0                         10.0
# 37                         18.0                         29.0
# 38                          7.0                          5.0
# 39                          4.0                         17.0
# 40                         12.0                         17.0
# 41                          4.0                         20.0
# 42                         15.0                          6.0
# 43                          6.0                          0.0
# 44                         20.0                          6.0
# 45                          9.0                          8.0
# 46                         43.0                         45.0
# 47                          6.0                         17.0
# 48                         46.0                         46.0
# 49                         11.0                         34.0
# 50                          1.0                          6.0
# 51                         39.0                         32.0
# 52                         39.0                         41.0
# 53                         42.0                         26.0
# 54                          6.0                          2.0
#
# [55 rows x 61 columns]
