# %%
import sys
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import *
from sklearn.svm import SVR
from score_metrics import rmse, spearman, mcc, multiclass_mcc

from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

# %%
def get_features_df(activities_file, compound_ft_file, target_ft_file=None):
    activities = pd.read_csv(activities_file, sep=',')
    compounds = pd.read_csv(compound_ft_file, sep=',')
    activities = activities[activities["type"] == "IC50"]
    activities = activities[["target_chembl_id",
                             "molecule_chembl_id", "standard_value"]].dropna()
    features = activities.merge(compounds, on="molecule_chembl_id")
    features["standard_value"] = features["standard_value"]/1000

    if target_ft_file:
        targets = pd.read_csv(target_ft_file, sep=',', header=None)
        targets.columns = ["target_chembl_id"] + \
            [f"prot_ft_{i}" for i in range(targets.shape[1]-1)]
        features = features[features["target_chembl_id"].isin(
            targets["target_chembl_id"])]
        features = features.merge(targets, on="target_chembl_id")

    features.to_csv("features.csv", index=False)
    return features

# %%
def get_docking_features_df(docking_file, compound_ft_file, target_ft_file):
    docking = pd.read_csv(docking_file, sep=',')
    compounds = pd.read_csv(compound_ft_file, sep=',')
    docking["target_chembl_id"] = "CHEMBL4523582"
    docking = docking[["target_chembl_id", "chembl_id", "docking score"]].dropna()
    docking.rename({"chembl_id":"molecule_chembl_id"}, axis=1, inplace=True)
    features = docking.merge(compounds, on="molecule_chembl_id")

    targets = pd.read_csv(target_ft_file, sep=',', header=None)
    targets.columns = ["target_chembl_id"] + \
        [f"prot_ft_{i}" for i in range(targets.shape[1]-1)]
    features = features[features["target_chembl_id"].isin(
        targets["target_chembl_id"])]
    features = features.merge(targets, on="target_chembl_id")

    features.to_csv("features_docking.csv", index=False)
    return features

# %%
def SVR_model(input, pred_value="standard_value", out_file="SVR_model_test.tsv"):
    input = input.sample(frac=1, random_state=0).reset_index(drop=True)
    y = input[pred_value]
    X_train, X_test, y_train, y_test = train_test_split(input, y, test_size=0.2, random_state=0)

    if "prot_ft_0" in X_train.columns: # if we use protein features
        prot_cols = [col for col in X_train.columns if col.startswith("prot_ft")]
        scaler = MinMaxScaler()
        X_train[prot_cols] = scaler.fit_transform(X_train[prot_cols])
        X_test[prot_cols] = scaler.transform(X_test[prot_cols])

    # find best parameters
    param_grid = {'C': [10, 1000, 5000, 10000, 50000], 'gamma': [0.01, 0.05, 0.1, 0.5, 1]}
    gs = GridSearchCV(SVR(), param_grid, cv=10, n_jobs=1, scoring='neg_root_mean_squared_error', verbose=3)
    gs.fit(X_train.iloc[:, 3:], y_train)
    print("Grid Search")
    print("best params: ", gs.best_params_)
    print(pd.concat([pd.DataFrame(gs.cv_results_["params"]), pd.DataFrame(-gs.cv_results_["mean_test_score"], columns=["RMSE"])],axis=1))

    # test
    model = SVR(C=gs.best_params_['C'], gamma=gs.best_params_['gamma'])
    model.fit(X_train.iloc[:, 3:], y_train)
    pred = model.predict(X_test.iloc[:, 3:])
    test_result = X_test.iloc[:, :3]
    test_result['predicted'] = pred
    test_result.to_csv(out_file, sep="\t", index=False)
    print("Test set results:")
    print(f"RMSE: {rmse(pred, y_test)}, Spearman: {spearman(pred, y_test)}, MCC: {mcc(pred, y_test.to_numpy(), np.median(y_test))}")
    return model

# %%
def RF_model(input, pred_value="standard_value", out_file="RF_model_test.tsv"):
    input = input.sample(frac=1, random_state=0).reset_index(drop=True)
    y = input[pred_value]
    X_train, X_test, y_train, y_test = train_test_split(input, y, test_size=0.2, random_state=0)

    if "prot_ft_0" in X_train.columns: # if we use protein features
        prot_cols = [col for col in X_train.columns if col.startswith("prot_ft")]
        scaler = MinMaxScaler()
        X_train[prot_cols] = scaler.fit_transform(X_train[prot_cols])
        X_test[prot_cols] = scaler.transform(X_test[prot_cols])

    # find best parameters
    param_grid = {'n_estimators': [10, 50, 100, 500], 'max_features': ['sqrt', 'log2'], 'max_depth': [10, 20, 50, 100]}
    gs = GridSearchCV(RandomForestRegressor(), param_grid, cv=10, n_jobs=1, scoring='neg_root_mean_squared_error', verbose=3)
    gs.fit(X_train.iloc[:, 3:], y_train)
    print("Grid Search")
    print("best params: ", gs.best_params_)
    print(pd.concat([pd.DataFrame(gs.cv_results_["params"]), pd.DataFrame(-gs.cv_results_["mean_test_score"], columns=["RMSE"])],axis=1))

    # test
    model = RandomForestRegressor(n_estimators=gs.best_params_['n_estimators'], max_features=gs.best_params_['max_features'], max_depth=gs.best_params_['max_depth'])
    model.fit(X_train.iloc[:, 3:], y_train)
    pred = model.predict(X_test.iloc[:, 3:])
    test_result = X_test.iloc[:, :3]
    test_result['predicted'] = pred
    test_result.to_csv(out_file, sep="\t", index=False)
    print("Test set results:")
    print(f"RMSE: {rmse(pred, y_test)}, Spearman: {spearman(pred, y_test)}, MCC: {mcc(pred, y_test.to_numpy(), np.median(y_test))}")
    return model

# %%
activities_file = "activities.csv"
compound_ft_file = "ligands_ecfp4.csv"
target_ft_file = "targets_embedding.csv"

input = get_features_df(activities_file, compound_ft_file, target_ft_file)
svr = SVR_model(input)
# Out:
# Grid Search
# best params:  {'C': 10000, 'gamma': 0.05}
#            C  gamma       RMSE
# 0        0.1  0.001  30.293021
# 1        0.1  0.005  29.938034
# 2        0.1  0.010  29.970752
# 3        0.1  0.050  30.430278
# 4        0.1  0.100  30.523872
# 5        0.1  0.500  30.579028
# 6        0.1  1.000  30.580412
# 7       10.0  0.001  27.556163
# 8       10.0  0.005  26.310064
# 9       10.0  0.010  25.263038
# 10      10.0  0.050  23.655354
# 11      10.0  0.100  24.527894
# 12      10.0  0.500  26.059362
# 13      10.0  1.000  26.123304
# 14    1000.0  0.001  20.878570
# 15    1000.0  0.005  17.527031
# 16    1000.0  0.010  17.942156
# 17    1000.0  0.050  17.417289
# 18    1000.0  0.100  17.426527
# 19    1000.0  0.500  20.013791
# 20    1000.0  1.000  21.177231
# 21    5000.0  0.001  17.912419
# 22    5000.0  0.005  18.023761
# 23    5000.0  0.010  17.904481
# 24    5000.0  0.050  17.417289
# 25    5000.0  0.100  17.426527
# 26    5000.0  0.500  20.013791
# 27    5000.0  1.000  21.177231
# 28   10000.0  0.001  18.009704
# 29   10000.0  0.005  18.024341
# 30   10000.0  0.010  17.904461
# 31   10000.0  0.050  17.417289
# 32   10000.0  0.100  17.426527
# 33   10000.0  0.500  20.013791
# 34   10000.0  1.000  21.177231
# 35   50000.0  0.001  18.562011
# 36   50000.0  0.005  18.024337
# 37   50000.0  0.010  17.904459
# 38   50000.0  0.050  17.417289
# 39   50000.0  0.100  17.426527
# 40   50000.0  0.500  20.013791
# 41   50000.0  1.000  21.177231
# 42  100000.0  0.001  18.563799
# 43  100000.0  0.005  18.024339
# 44  100000.0  0.010  17.904470
# 45  100000.0  0.050  17.417289
# 46  100000.0  0.100  17.426527
# 47  100000.0  0.500  20.013791
# 48  100000.0  1.000  21.177231
# Test set results:
# RMSE: 16.497003174461916, Spearman: 0.6467181139522268, MCC: 0.4666666666666667

# %%
rf = RF_model(input)
# Out:
# Fitting 20 folds for each of 100 candidates, totalling 2000 fits
# Grid Search
# best params:  {'bootstrap': False, 'max_depth': 50, 'max_features': 'sqrt', 'n_estimators': 10}
#     bootstrap  max_depth max_features  n_estimators       RMSE
# 0       False          5         sqrt            10  23.386535
# 1       False          5         sqrt            50  22.042334
# 2       False          5         sqrt           100  22.302992
# 3       False          5         sqrt           500  22.048880
# 4       False          5         sqrt          1000  22.078448
# ..        ...        ...          ...           ...        ...
# 95       True        100         log2            10  19.622996
# 96       True        100         log2            50  18.887482
# 97       True        100         log2           100  18.723559
# 98       True        100         log2           500  18.624244
# 99       True        100         log2          1000  18.707181
#
# [100 rows x 5 columns]
# Test set results:
# RMSE: 14.14955726412044, Spearman: 0.658257845168558, MCC: 0.3143473067309658

# %%
docking_file = "7rdx_ADP_docking.csv"
compound_ft_file = "ligands_ecfp4.csv"
target_ft_file = "targets_embedding.csv"

input = get_docking_features_df(docking_file, compound_ft_file, target_ft_file)
svr = SVR_model(input, pred_value="docking score", out_file="SVR_docking_model_test.tsv")
# Out:
# [CV 5/10] END .............C=50000, gamma=0.01;, score=-1.066 total time=   3.6s
# [CV 6/10] END .............C=50000, gamma=0.01;, score=-1.107 total time=   4.0s
# [CV 7/10] END .............C=50000, gamma=0.01;, score=-1.092 total time=   3.7s
# [CV 8/10] END .............C=50000, gamma=0.01;, score=-0.966 total time=   4.0s
# [CV 9/10] END .............C=50000, gamma=0.01;, score=-1.012 total time=   4.0s
# [CV 10/10] END ............C=50000, gamma=0.01;, score=-1.025 total time=   3.9s
# [CV 1/10] END .............C=50000, gamma=0.05;, score=-1.048 total time=   3.6s
# [CV 2/10] END .............C=50000, gamma=0.05;, score=-1.066 total time=   3.7s
# [CV 3/10] END .............C=50000, gamma=0.05;, score=-1.036 total time=   3.7s
# [CV 4/10] END .............C=50000, gamma=0.05;, score=-1.102 total time=   3.7s
# [CV 5/10] END .............C=50000, gamma=0.05;, score=-1.057 total time=   3.6s
# [CV 6/10] END .............C=50000, gamma=0.05;, score=-1.076 total time=   3.8s
# [CV 7/10] END .............C=50000, gamma=0.05;, score=-1.084 total time=   9.7s
# [CV 8/10] END .............C=50000, gamma=0.05;, score=-0.954 total time=   4.6s
# [CV 9/10] END .............C=50000, gamma=0.05;, score=-0.991 total time=   3.6s
# [CV 10/10] END ............C=50000, gamma=0.05;, score=-1.027 total time=   3.6s
# [CV 1/10] END ..............C=50000, gamma=0.1;, score=-1.051 total time=   3.8s
# [CV 2/10] END ..............C=50000, gamma=0.1;, score=-1.079 total time=   3.6s
# [CV 3/10] END ..............C=50000, gamma=0.1;, score=-1.043 total time=   3.6s
# [CV 4/10] END ..............C=50000, gamma=0.1;, score=-1.099 total time=   3.9s
# [CV 5/10] END ..............C=50000, gamma=0.1;, score=-1.062 total time=   4.0s
# [CV 6/10] END ..............C=50000, gamma=0.1;, score=-1.067 total time=   3.6s
# [CV 7/10] END ..............C=50000, gamma=0.1;, score=-1.089 total time=   3.7s
# [CV 8/10] END ..............C=50000, gamma=0.1;, score=-0.958 total time=   3.7s
# [CV 9/10] END ..............C=50000, gamma=0.1;, score=-0.997 total time=   3.7s
# [CV 10/10] END .............C=50000, gamma=0.1;, score=-1.045 total time=   3.8s
# [CV 1/10] END ..............C=50000, gamma=0.5;, score=-1.082 total time=   3.5s
# [CV 2/10] END ..............C=50000, gamma=0.5;, score=-1.087 total time=   3.5s
# [CV 3/10] END ..............C=50000, gamma=0.5;, score=-1.054 total time=   3.6s
# [CV 4/10] END ..............C=50000, gamma=0.5;, score=-1.111 total time=   4.0s
# [CV 5/10] END ..............C=50000, gamma=0.5;, score=-1.068 total time=   3.8s
# [CV 6/10] END ..............C=50000, gamma=0.5;, score=-1.085 total time=   3.6s
# [CV 7/10] END ..............C=50000, gamma=0.5;, score=-1.104 total time=   3.9s
# [CV 8/10] END ..............C=50000, gamma=0.5;, score=-0.972 total time=   3.5s
# [CV 9/10] END ..............C=50000, gamma=0.5;, score=-1.021 total time=   3.4s
# [CV 10/10] END .............C=50000, gamma=0.5;, score=-1.076 total time=   3.8s
# [CV 1/10] END ................C=50000, gamma=1;, score=-1.089 total time=   3.6s
# [CV 2/10] END ................C=50000, gamma=1;, score=-1.088 total time=   3.5s
# [CV 3/10] END ................C=50000, gamma=1;, score=-1.054 total time=   3.8s
# [CV 4/10] END ................C=50000, gamma=1;, score=-1.112 total time=   4.0s
# [CV 5/10] END ................C=50000, gamma=1;, score=-1.068 total time=   3.6s
# [CV 6/10] END ................C=50000, gamma=1;, score=-1.086 total time=   3.9s
# [CV 7/10] END ................C=50000, gamma=1;, score=-1.118 total time=   3.5s
# [CV 8/10] END ................C=50000, gamma=1;, score=-0.973 total time=   3.5s
# [CV 9/10] END ................C=50000, gamma=1;, score=-1.025 total time=   3.7s
# [CV 10/10] END ...............C=50000, gamma=1;, score=-1.077 total time=   3.7s
# Grid Search
# best params:  {'C': 10, 'gamma': 0.01}
#         C  gamma      RMSE
# 0      10   0.01  1.017998
# 1      10   0.05  1.043801
# 2      10   0.10  1.048956
# 3      10   0.50  1.066057
# 4      10   1.00  1.069027
# 5    1000   0.01  1.054995
# 6    1000   0.05  1.044183
# 7    1000   0.10  1.048951
# 8    1000   0.50  1.066057
# 9    1000   1.00  1.069027
# 10   5000   0.01  1.055008
# 11   5000   0.05  1.044180
# 12   5000   0.10  1.048951
# 13   5000   0.50  1.066056
# 14   5000   1.00  1.069025
# 15  10000   0.01  1.054999
# 16  10000   0.05  1.044179
# 17  10000   0.10  1.048954
# 18  10000   0.50  1.066057
# 19  10000   1.00  1.069027
# 20  50000   0.01  1.055002
# 21  50000   0.05  1.044179
# 22  50000   0.10  1.048952
# 23  50000   0.50  1.066056
# 24  50000   1.00  1.069026
# Test set results:
# RMSE: 1.0608197371288288, Spearman: 0.524028552144139, MCC: 0.43189092659663647

# %%
rf = RF_model(input, pred_value="docking score", out_file="RF_docking_model_test.tsv")
# Out:
# Fitting 10 folds for each of 32 candidates, totalling 320 fits
# [CV 1/10] END max_depth=10, max_features=sqrt, n_estimators=10;, score=-1.064 total time=   0.2s
# [CV 2/10] END max_depth=10, max_features=sqrt, n_estimators=10;, score=-1.045 total time=   0.2s
# [CV 3/10] END max_depth=10, max_features=sqrt, n_estimators=10;, score=-1.028 total time=   0.2s
# [CV 4/10] END max_depth=10, max_features=sqrt, n_estimators=10;, score=-0.970 total time=   0.2s
# [CV 5/10] END max_depth=10, max_features=sqrt, n_estimators=10;, score=-0.951 total time=   0.2s
# [CV 6/10] END max_depth=10, max_features=sqrt, n_estimators=10;, score=-0.897 total time=   0.2s
# [CV 7/10] END max_depth=10, max_features=sqrt, n_estimators=10;, score=-0.975 total time=   0.1s
# [CV 8/10] END max_depth=10, max_features=sqrt, n_estimators=10;, score=-0.898 total time=   0.2s
# [CV 9/10] END max_depth=10, max_features=sqrt, n_estimators=10;, score=-0.929 total time=   0.2s
# [CV 10/10] END max_depth=10, max_features=sqrt, n_estimators=10;, score=-1.073 total time=   0.2s
# [CV 1/10] END max_depth=10, max_features=sqrt, n_estimators=50;, score=-1.045 total time=   0.5s
# [CV 2/10] END max_depth=10, max_features=sqrt, n_estimators=50;, score=-1.056 total time=   0.5s
# [CV 3/10] END max_depth=10, max_features=sqrt, n_estimators=50;, score=-1.011 total time=   0.5s
# [CV 4/10] END max_depth=10, max_features=sqrt, n_estimators=50;, score=-0.960 total time=   0.5s
# [CV 5/10] END max_depth=10, max_features=sqrt, n_estimators=50;, score=-0.948 total time=   0.5s
# [CV 6/10] END max_depth=10, max_features=sqrt, n_estimators=50;, score=-0.917 total time=   0.5s
# [CV 7/10] END max_depth=10, max_features=sqrt, n_estimators=50;, score=-0.968 total time=   0.5s
# [CV 8/10] END max_depth=10, max_features=sqrt, n_estimators=50;, score=-0.913 total time=   0.5s
# [CV 9/10] END max_depth=10, max_features=sqrt, n_estimators=50;, score=-0.911 total time=   0.5s
# [CV 10/10] END max_depth=10, max_features=sqrt, n_estimators=50;, score=-1.033 total time=   0.5s
# [CV 1/10] END max_depth=10, max_features=sqrt, n_estimators=100;, score=-1.043 total time=   1.3s
# [CV 2/10] END max_depth=10, max_features=sqrt, n_estimators=100;, score=-1.044 total time=   1.2s
# [CV 3/10] END max_depth=10, max_features=sqrt, n_estimators=100;, score=-1.008 total time=   0.9s
# [CV 4/10] END max_depth=10, max_features=sqrt, n_estimators=100;, score=-0.951 total time=   0.9s
# [CV 5/10] END max_depth=10, max_features=sqrt, n_estimators=100;, score=-0.953 total time=   0.9s
# [CV 6/10] END max_depth=10, max_features=sqrt, n_estimators=100;, score=-0.904 total time=   0.9s
# [CV 7/10] END max_depth=10, max_features=sqrt, n_estimators=100;, score=-0.965 total time=   0.9s
# [CV 8/10] END max_depth=10, max_features=sqrt, n_estimators=100;, score=-0.910 total time=   0.9s
# [CV 9/10] END max_depth=10, max_features=sqrt, n_estimators=100;, score=-0.917 total time=   1.0s
# [CV 10/10] END max_depth=10, max_features=sqrt, n_estimators=100;, score=-1.050 total time=   1.4s
# [CV 1/10] END max_depth=10, max_features=sqrt, n_estimators=500;, score=-1.041 total time=   5.7s
# [CV 2/10] END max_depth=10, max_features=sqrt, n_estimators=500;, score=-1.043 total time=   4.2s
# [CV 3/10] END max_depth=10, max_features=sqrt, n_estimators=500;, score=-1.009 total time=   4.2s
# [CV 4/10] END max_depth=10, max_features=sqrt, n_estimators=500;, score=-0.951 total time=   4.8s
# [CV 5/10] END max_depth=10, max_features=sqrt, n_estimators=500;, score=-0.953 total time=   4.6s
# [CV 6/10] END max_depth=10, max_features=sqrt, n_estimators=500;, score=-0.906 total time=   6.3s
# [CV 7/10] END max_depth=10, max_features=sqrt, n_estimators=500;, score=-0.970 total time=   5.7s
# [CV 8/10] END max_depth=10, max_features=sqrt, n_estimators=500;, score=-0.904 total time=   6.3s
# [CV 9/10] END max_depth=10, max_features=sqrt, n_estimators=500;, score=-0.905 total time=   4.2s
# [CV 10/10] END max_depth=10, max_features=sqrt, n_estimators=500;, score=-1.041 total time=   4.3s
# [CV 1/10] END max_depth=10, max_features=log2, n_estimators=10;, score=-1.103 total time=   0.1s
# [CV 2/10] END max_depth=10, max_features=log2, n_estimators=10;, score=-1.156 total time=   0.1s
# [CV 3/10] END max_depth=10, max_features=log2, n_estimators=10;, score=-1.045 total time=   0.1s
# [CV 4/10] END max_depth=10, max_features=log2, n_estimators=10;, score=-1.028 total time=   0.1s
# [CV 5/10] END max_depth=10, max_features=log2, n_estimators=10;, score=-0.988 total time=   0.1s
# [CV 6/10] END max_depth=10, max_features=log2, n_estimators=10;, score=-0.986 total time=   0.2s
# [CV 7/10] END max_depth=10, max_features=log2, n_estimators=10;, score=-0.997 total time=   0.2s
# [CV 8/10] END max_depth=10, max_features=log2, n_estimators=10;, score=-1.036 total time=   0.2s
# [CV 9/10] END max_depth=10, max_features=log2, n_estimators=10;, score=-0.982 total time=   0.2s
# [CV 10/10] END max_depth=10, max_features=log2, n_estimators=10;, score=-1.149 total time=   0.2s
# [CV 1/10] END max_depth=10, max_features=log2, n_estimators=50;, score=-1.088 total time=   0.5s
# [CV 2/10] END max_depth=10, max_features=log2, n_estimators=50;, score=-1.118 total time=   0.5s
# [CV 3/10] END max_depth=10, max_features=log2, n_estimators=50;, score=-1.054 total time=   0.3s
# [CV 4/10] END max_depth=10, max_features=log2, n_estimators=50;, score=-0.998 total time=   0.3s
# [CV 5/10] END max_depth=10, max_features=log2, n_estimators=50;, score=-1.003 total time=   0.4s
# [CV 6/10] END max_depth=10, max_features=log2, n_estimators=50;, score=-0.951 total time=   0.3s
# [CV 7/10] END max_depth=10, max_features=log2, n_estimators=50;, score=-1.023 total time=   0.3s
# [CV 8/10] END max_depth=10, max_features=log2, n_estimators=50;, score=-1.027 total time=   0.3s
# [CV 9/10] END max_depth=10, max_features=log2, n_estimators=50;, score=-1.001 total time=   0.3s
# [CV 10/10] END max_depth=10, max_features=log2, n_estimators=50;, score=-1.123 total time=   0.3s
# [CV 1/10] END max_depth=10, max_features=log2, n_estimators=100;, score=-1.089 total time=   0.7s
# [CV 2/10] END max_depth=10, max_features=log2, n_estimators=100;, score=-1.119 total time=   0.6s
# [CV 3/10] END max_depth=10, max_features=log2, n_estimators=100;, score=-1.062 total time=   0.6s
# [CV 4/10] END max_depth=10, max_features=log2, n_estimators=100;, score=-1.000 total time=   0.6s
# [CV 5/10] END max_depth=10, max_features=log2, n_estimators=100;, score=-0.989 total time=   0.6s
# [CV 6/10] END max_depth=10, max_features=log2, n_estimators=100;, score=-0.960 total time=   0.6s
# [CV 7/10] END max_depth=10, max_features=log2, n_estimators=100;, score=-1.022 total time=   0.6s
# [CV 8/10] END max_depth=10, max_features=log2, n_estimators=100;, score=-1.013 total time=   0.6s
# [CV 9/10] END max_depth=10, max_features=log2, n_estimators=100;, score=-1.003 total time=   0.6s
# [CV 10/10] END max_depth=10, max_features=log2, n_estimators=100;, score=-1.127 total time=   0.6s
# [CV 1/10] END max_depth=10, max_features=log2, n_estimators=500;, score=-1.090 total time=   3.3s
# [CV 2/10] END max_depth=10, max_features=log2, n_estimators=500;, score=-1.123 total time=   2.7s
# [CV 3/10] END max_depth=10, max_features=log2, n_estimators=500;, score=-1.061 total time=   2.7s
# [CV 4/10] END max_depth=10, max_features=log2, n_estimators=500;, score=-1.007 total time=   3.4s
# [CV 5/10] END max_depth=10, max_features=log2, n_estimators=500;, score=-0.995 total time=   3.4s
# [CV 6/10] END max_depth=10, max_features=log2, n_estimators=500;, score=-0.965 total time=   2.7s
# [CV 7/10] END max_depth=10, max_features=log2, n_estimators=500;, score=-1.021 total time=   2.7s
# [CV 8/10] END max_depth=10, max_features=log2, n_estimators=500;, score=-1.018 total time=   2.6s
# [CV 9/10] END max_depth=10, max_features=log2, n_estimators=500;, score=-1.000 total time=   3.3s
# [CV 10/10] END max_depth=10, max_features=log2, n_estimators=500;, score=-1.127 total time=   2.7s
# [CV 1/10] END max_depth=20, max_features=sqrt, n_estimators=10;, score=-0.981 total time=   0.2s
# [CV 2/10] END max_depth=20, max_features=sqrt, n_estimators=10;, score=-0.985 total time=   0.2s
# [CV 3/10] END max_depth=20, max_features=sqrt, n_estimators=10;, score=-0.986 total time=   0.3s
# [CV 4/10] END max_depth=20, max_features=sqrt, n_estimators=10;, score=-0.929 total time=   0.2s
# [CV 5/10] END max_depth=20, max_features=sqrt, n_estimators=10;, score=-0.953 total time=   0.3s
# [CV 6/10] END max_depth=20, max_features=sqrt, n_estimators=10;, score=-0.963 total time=   0.2s
# [CV 7/10] END max_depth=20, max_features=sqrt, n_estimators=10;, score=-0.994 total time=   0.3s
# [CV 8/10] END max_depth=20, max_features=sqrt, n_estimators=10;, score=-0.888 total time=   0.3s
# [CV 9/10] END max_depth=20, max_features=sqrt, n_estimators=10;, score=-0.866 total time=   0.2s
# [CV 10/10] END max_depth=20, max_features=sqrt, n_estimators=10;, score=-0.979 total time=   0.2s
# [CV 1/10] END max_depth=20, max_features=sqrt, n_estimators=50;, score=-1.006 total time=   0.9s
# [CV 2/10] END max_depth=20, max_features=sqrt, n_estimators=50;, score=-0.980 total time=   0.9s
# [CV 3/10] END max_depth=20, max_features=sqrt, n_estimators=50;, score=-0.965 total time=   0.9s
# [CV 4/10] END max_depth=20, max_features=sqrt, n_estimators=50;, score=-0.952 total time=   0.9s
# [CV 5/10] END max_depth=20, max_features=sqrt, n_estimators=50;, score=-0.941 total time=   0.9s
# [CV 6/10] END max_depth=20, max_features=sqrt, n_estimators=50;, score=-0.926 total time=   1.5s
# [CV 7/10] END max_depth=20, max_features=sqrt, n_estimators=50;, score=-0.983 total time=   1.2s
# [CV 8/10] END max_depth=20, max_features=sqrt, n_estimators=50;, score=-0.856 total time=   0.9s
# [CV 9/10] END max_depth=20, max_features=sqrt, n_estimators=50;, score=-0.861 total time=   0.9s
# [CV 10/10] END max_depth=20, max_features=sqrt, n_estimators=50;, score=-0.972 total time=   0.9s
# [CV 1/10] END max_depth=20, max_features=sqrt, n_estimators=100;, score=-0.988 total time=   1.8s
# [CV 2/10] END max_depth=20, max_features=sqrt, n_estimators=100;, score=-0.974 total time=   2.5s
# [CV 3/10] END max_depth=20, max_features=sqrt, n_estimators=100;, score=-0.979 total time=   1.8s
# [CV 4/10] END max_depth=20, max_features=sqrt, n_estimators=100;, score=-0.951 total time=   2.4s
# [CV 5/10] END max_depth=20, max_features=sqrt, n_estimators=100;, score=-0.939 total time=   1.7s
# [CV 6/10] END max_depth=20, max_features=sqrt, n_estimators=100;, score=-0.927 total time=   1.8s
# [CV 7/10] END max_depth=20, max_features=sqrt, n_estimators=100;, score=-0.985 total time=   1.7s
# [CV 8/10] END max_depth=20, max_features=sqrt, n_estimators=100;, score=-0.856 total time=   1.8s
# [CV 9/10] END max_depth=20, max_features=sqrt, n_estimators=100;, score=-0.852 total time=   1.8s
# [CV 10/10] END max_depth=20, max_features=sqrt, n_estimators=100;, score=-0.964 total time=   2.0s
# [CV 1/10] END max_depth=20, max_features=sqrt, n_estimators=500;, score=-0.989 total time=   9.0s
# [CV 2/10] END max_depth=20, max_features=sqrt, n_estimators=500;, score=-0.972 total time=  10.2s
# [CV 3/10] END max_depth=20, max_features=sqrt, n_estimators=500;, score=-0.968 total time=   9.2s
# [CV 4/10] END max_depth=20, max_features=sqrt, n_estimators=500;, score=-0.953 total time=   9.1s
# [CV 5/10] END max_depth=20, max_features=sqrt, n_estimators=500;, score=-0.932 total time=   8.5s
# [CV 6/10] END max_depth=20, max_features=sqrt, n_estimators=500;, score=-0.928 total time=   9.9s
# [CV 7/10] END max_depth=20, max_features=sqrt, n_estimators=500;, score=-0.977 total time=   9.9s
# [CV 8/10] END max_depth=20, max_features=sqrt, n_estimators=500;, score=-0.855 total time=   9.3s
# [CV 9/10] END max_depth=20, max_features=sqrt, n_estimators=500;, score=-0.858 total time=   9.0s
# [CV 10/10] END max_depth=20, max_features=sqrt, n_estimators=500;, score=-0.970 total time=   9.2s
# [CV 1/10] END max_depth=20, max_features=log2, n_estimators=10;, score=-1.008 total time=   0.2s
# [CV 2/10] END max_depth=20, max_features=log2, n_estimators=10;, score=-1.047 total time=   0.2s
# [CV 3/10] END max_depth=20, max_features=log2, n_estimators=10;, score=-1.027 total time=   0.2s
# [CV 4/10] END max_depth=20, max_features=log2, n_estimators=10;, score=-0.963 total time=   0.2s
# [CV 5/10] END max_depth=20, max_features=log2, n_estimators=10;, score=-0.936 total time=   0.2s
# [CV 6/10] END max_depth=20, max_features=log2, n_estimators=10;, score=-0.965 total time=   0.3s
# [CV 7/10] END max_depth=20, max_features=log2, n_estimators=10;, score=-0.978 total time=   0.3s
# [CV 8/10] END max_depth=20, max_features=log2, n_estimators=10;, score=-0.898 total time=   0.3s
# [CV 9/10] END max_depth=20, max_features=log2, n_estimators=10;, score=-0.918 total time=   0.3s
# [CV 10/10] END max_depth=20, max_features=log2, n_estimators=10;, score=-1.048 total time=   0.3s
# [CV 1/10] END max_depth=20, max_features=log2, n_estimators=50;, score=-1.017 total time=   1.3s
# [CV 2/10] END max_depth=20, max_features=log2, n_estimators=50;, score=-1.019 total time=   1.6s
# [CV 3/10] END max_depth=20, max_features=log2, n_estimators=50;, score=-0.991 total time=   1.8s
# [CV 4/10] END max_depth=20, max_features=log2, n_estimators=50;, score=-0.953 total time=   0.8s
# [CV 5/10] END max_depth=20, max_features=log2, n_estimators=50;, score=-0.936 total time=   0.7s
# [CV 6/10] END max_depth=20, max_features=log2, n_estimators=50;, score=-0.941 total time=   0.7s
# [CV 7/10] END max_depth=20, max_features=log2, n_estimators=50;, score=-0.967 total time=   0.7s
# [CV 8/10] END max_depth=20, max_features=log2, n_estimators=50;, score=-0.908 total time=   0.7s
# [CV 9/10] END max_depth=20, max_features=log2, n_estimators=50;, score=-0.907 total time=   0.7s
# [CV 10/10] END max_depth=20, max_features=log2, n_estimators=50;, score=-1.013 total time=   0.7s
# [CV 1/10] END max_depth=20, max_features=log2, n_estimators=100;, score=-1.014 total time=   4.1s
# [CV 2/10] END max_depth=20, max_features=log2, n_estimators=100;, score=-1.014 total time=   2.4s
# [CV 3/10] END max_depth=20, max_features=log2, n_estimators=100;, score=-0.999 total time=   1.4s
# [CV 4/10] END max_depth=20, max_features=log2, n_estimators=100;, score=-0.945 total time=   1.4s
# [CV 5/10] END max_depth=20, max_features=log2, n_estimators=100;, score=-0.938 total time=   1.4s
# [CV 6/10] END max_depth=20, max_features=log2, n_estimators=100;, score=-0.918 total time=   1.4s
# [CV 7/10] END max_depth=20, max_features=log2, n_estimators=100;, score=-0.977 total time=   1.9s
# [CV 8/10] END max_depth=20, max_features=log2, n_estimators=100;, score=-0.897 total time=   2.5s
# [CV 9/10] END max_depth=20, max_features=log2, n_estimators=100;, score=-0.906 total time=   1.4s
# [CV 10/10] END max_depth=20, max_features=log2, n_estimators=100;, score=-1.026 total time=   1.4s
# [CV 1/10] END max_depth=20, max_features=log2, n_estimators=500;, score=-1.012 total time=   6.9s
# [CV 2/10] END max_depth=20, max_features=log2, n_estimators=500;, score=-1.017 total time=   9.4s
# [CV 3/10] END max_depth=20, max_features=log2, n_estimators=500;, score=-0.991 total time=  12.2s
# [CV 4/10] END max_depth=20, max_features=log2, n_estimators=500;, score=-0.949 total time=  11.5s
# [CV 5/10] END max_depth=20, max_features=log2, n_estimators=500;, score=-0.937 total time=   7.6s
# [CV 6/10] END max_depth=20, max_features=log2, n_estimators=500;, score=-0.929 total time=   6.8s
# [CV 7/10] END max_depth=20, max_features=log2, n_estimators=500;, score=-0.973 total time=   7.6s
# [CV 8/10] END max_depth=20, max_features=log2, n_estimators=500;, score=-0.891 total time=  13.7s
# [CV 9/10] END max_depth=20, max_features=log2, n_estimators=500;, score=-0.897 total time=   8.0s
# [CV 10/10] END max_depth=20, max_features=log2, n_estimators=500;, score=-1.012 total time=   6.8s
# [CV 1/10] END max_depth=50, max_features=sqrt, n_estimators=10;, score=-0.994 total time=   0.3s
# [CV 2/10] END max_depth=50, max_features=sqrt, n_estimators=10;, score=-0.966 total time=   0.3s
# [CV 3/10] END max_depth=50, max_features=sqrt, n_estimators=10;, score=-0.999 total time=   0.4s
# [CV 4/10] END max_depth=50, max_features=sqrt, n_estimators=10;, score=-1.035 total time=   1.4s
# [CV 5/10] END max_depth=50, max_features=sqrt, n_estimators=10;, score=-0.934 total time=   1.2s
# [CV 6/10] END max_depth=50, max_features=sqrt, n_estimators=10;, score=-1.014 total time=   0.7s
# [CV 7/10] END max_depth=50, max_features=sqrt, n_estimators=10;, score=-1.001 total time=   0.5s
# [CV 8/10] END max_depth=50, max_features=sqrt, n_estimators=10;, score=-0.883 total time=   0.4s
# [CV 9/10] END max_depth=50, max_features=sqrt, n_estimators=10;, score=-0.927 total time=   0.4s
# [CV 10/10] END max_depth=50, max_features=sqrt, n_estimators=10;, score=-0.961 total time=   0.4s
# [CV 1/10] END max_depth=50, max_features=sqrt, n_estimators=50;, score=-0.995 total time=   1.5s
# [CV 2/10] END max_depth=50, max_features=sqrt, n_estimators=50;, score=-0.949 total time=   2.1s
# [CV 3/10] END max_depth=50, max_features=sqrt, n_estimators=50;, score=-0.977 total time=   2.3s
# [CV 4/10] END max_depth=50, max_features=sqrt, n_estimators=50;, score=-0.975 total time=   2.2s
# [CV 5/10] END max_depth=50, max_features=sqrt, n_estimators=50;, score=-0.949 total time=   1.9s
# [CV 6/10] END max_depth=50, max_features=sqrt, n_estimators=50;, score=-0.971 total time=   1.5s
# [CV 7/10] END max_depth=50, max_features=sqrt, n_estimators=50;, score=-0.999 total time=   1.5s
# [CV 8/10] END max_depth=50, max_features=sqrt, n_estimators=50;, score=-0.880 total time=   1.4s
# [CV 9/10] END max_depth=50, max_features=sqrt, n_estimators=50;, score=-0.884 total time=   1.5s
# [CV 10/10] END max_depth=50, max_features=sqrt, n_estimators=50;, score=-0.948 total time=   1.9s
# [CV 1/10] END max_depth=50, max_features=sqrt, n_estimators=100;, score=-0.986 total time=   3.6s
# [CV 2/10] END max_depth=50, max_features=sqrt, n_estimators=100;, score=-0.966 total time=   2.8s
# [CV 3/10] END max_depth=50, max_features=sqrt, n_estimators=100;, score=-0.972 total time=   2.8s
# [CV 4/10] END max_depth=50, max_features=sqrt, n_estimators=100;, score=-0.983 total time=   2.8s
# [CV 5/10] END max_depth=50, max_features=sqrt, n_estimators=100;, score=-0.945 total time=   3.4s
# [CV 6/10] END max_depth=50, max_features=sqrt, n_estimators=100;, score=-0.992 total time=   3.3s
# [CV 7/10] END max_depth=50, max_features=sqrt, n_estimators=100;, score=-0.996 total time=   5.4s
# [CV 8/10] END max_depth=50, max_features=sqrt, n_estimators=100;, score=-0.876 total time=   4.7s
# [CV 9/10] END max_depth=50, max_features=sqrt, n_estimators=100;, score=-0.881 total time=   2.8s
# [CV 10/10] END max_depth=50, max_features=sqrt, n_estimators=100;, score=-0.960 total time=   3.3s
# [CV 1/10] END max_depth=50, max_features=sqrt, n_estimators=500;, score=-0.978 total time=  24.7s
# [CV 2/10] END max_depth=50, max_features=sqrt, n_estimators=500;, score=-0.956 total time=  19.6s
# [CV 3/10] END max_depth=50, max_features=sqrt, n_estimators=500;, score=-0.976 total time=  15.6s
# [CV 4/10] END max_depth=50, max_features=sqrt, n_estimators=500;, score=-0.980 total time=  16.3s
# [CV 5/10] END max_depth=50, max_features=sqrt, n_estimators=500;, score=-0.946 total time=  16.3s
# [CV 6/10] END max_depth=50, max_features=sqrt, n_estimators=500;, score=-0.995 total time=  14.2s
# [CV 7/10] END max_depth=50, max_features=sqrt, n_estimators=500;, score=-1.001 total time=  14.5s
# [CV 8/10] END max_depth=50, max_features=sqrt, n_estimators=500;, score=-0.876 total time=  18.0s
# [CV 9/10] END max_depth=50, max_features=sqrt, n_estimators=500;, score=-0.878 total time=  14.9s
# [CV 10/10] END max_depth=50, max_features=sqrt, n_estimators=500;, score=-0.947 total time=  23.1s
# [CV 1/10] END max_depth=50, max_features=log2, n_estimators=10;, score=-1.006 total time=   0.3s
# [CV 2/10] END max_depth=50, max_features=log2, n_estimators=10;, score=-0.984 total time=   0.3s
# [CV 3/10] END max_depth=50, max_features=log2, n_estimators=10;, score=-0.993 total time=   0.3s
# [CV 4/10] END max_depth=50, max_features=log2, n_estimators=10;, score=-0.979 total time=   0.3s
# [CV 5/10] END max_depth=50, max_features=log2, n_estimators=10;, score=-0.958 total time=   0.3s
# [CV 6/10] END max_depth=50, max_features=log2, n_estimators=10;, score=-1.005 total time=   0.3s
# [CV 7/10] END max_depth=50, max_features=log2, n_estimators=10;, score=-1.006 total time=   0.3s
# [CV 8/10] END max_depth=50, max_features=log2, n_estimators=10;, score=-0.859 total time=   0.3s
# [CV 9/10] END max_depth=50, max_features=log2, n_estimators=10;, score=-0.906 total time=   0.4s
# [CV 10/10] END max_depth=50, max_features=log2, n_estimators=10;, score=-0.951 total time=   0.3s
# [CV 1/10] END max_depth=50, max_features=log2, n_estimators=50;, score=-0.984 total time=   1.4s
# [CV 2/10] END max_depth=50, max_features=log2, n_estimators=50;, score=-0.970 total time=   1.3s
# [CV 3/10] END max_depth=50, max_features=log2, n_estimators=50;, score=-0.976 total time=   1.4s
# [CV 4/10] END max_depth=50, max_features=log2, n_estimators=50;, score=-0.986 total time=   2.0s
# [CV 5/10] END max_depth=50, max_features=log2, n_estimators=50;, score=-0.937 total time=   1.4s
# [CV 6/10] END max_depth=50, max_features=log2, n_estimators=50;, score=-0.986 total time=   1.4s
# [CV 7/10] END max_depth=50, max_features=log2, n_estimators=50;, score=-1.006 total time=   1.9s
# [CV 8/10] END max_depth=50, max_features=log2, n_estimators=50;, score=-0.879 total time=   1.7s
# [CV 9/10] END max_depth=50, max_features=log2, n_estimators=50;, score=-0.863 total time=   1.4s
# [CV 10/10] END max_depth=50, max_features=log2, n_estimators=50;, score=-0.954 total time=   1.4s
# [CV 1/10] END max_depth=50, max_features=log2, n_estimators=100;, score=-0.979 total time=   3.4s
# [CV 2/10] END max_depth=50, max_features=log2, n_estimators=100;, score=-0.964 total time=   2.7s
# [CV 3/10] END max_depth=50, max_features=log2, n_estimators=100;, score=-0.975 total time=   2.7s
# [CV 4/10] END max_depth=50, max_features=log2, n_estimators=100;, score=-0.978 total time=   2.7s
# [CV 5/10] END max_depth=50, max_features=log2, n_estimators=100;, score=-0.942 total time=   3.3s
# [CV 6/10] END max_depth=50, max_features=log2, n_estimators=100;, score=-0.976 total time=   2.7s
# [CV 7/10] END max_depth=50, max_features=log2, n_estimators=100;, score=-0.999 total time=   2.7s
# [CV 8/10] END max_depth=50, max_features=log2, n_estimators=100;, score=-0.868 total time=   2.7s
# [CV 9/10] END max_depth=50, max_features=log2, n_estimators=100;, score=-0.867 total time=   3.3s
# [CV 10/10] END max_depth=50, max_features=log2, n_estimators=100;, score=-0.955 total time=   3.0s
# [CV 1/10] END max_depth=50, max_features=log2, n_estimators=500;, score=-0.984 total time=  14.2s
# [CV 2/10] END max_depth=50, max_features=log2, n_estimators=500;, score=-0.961 total time=  13.5s
# [CV 3/10] END max_depth=50, max_features=log2, n_estimators=500;, score=-0.974 total time=  14.8s
# [CV 4/10] END max_depth=50, max_features=log2, n_estimators=500;, score=-0.974 total time=  14.5s
# [CV 5/10] END max_depth=50, max_features=log2, n_estimators=500;, score=-0.944 total time=  14.4s
# [CV 6/10] END max_depth=50, max_features=log2, n_estimators=500;, score=-0.981 total time=  13.5s
# [CV 7/10] END max_depth=50, max_features=log2, n_estimators=500;, score=-1.002 total time=  14.4s
# [CV 8/10] END max_depth=50, max_features=log2, n_estimators=500;, score=-0.869 total time=  14.6s
# [CV 9/10] END max_depth=50, max_features=log2, n_estimators=500;, score=-0.875 total time=  14.2s
# [CV 10/10] END max_depth=50, max_features=log2, n_estimators=500;, score=-0.951 total time=  14.9s
# [CV 1/10] END max_depth=100, max_features=sqrt, n_estimators=10;, score=-0.995 total time=   0.4s
# [CV 2/10] END max_depth=100, max_features=sqrt, n_estimators=10;, score=-0.969 total time=   0.4s
# [CV 3/10] END max_depth=100, max_features=sqrt, n_estimators=10;, score=-0.984 total time=   0.4s
# [CV 4/10] END max_depth=100, max_features=sqrt, n_estimators=10;, score=-0.982 total time=   0.4s
# [CV 5/10] END max_depth=100, max_features=sqrt, n_estimators=10;, score=-0.946 total time=   0.4s
# [CV 6/10] END max_depth=100, max_features=sqrt, n_estimators=10;, score=-1.029 total time=   0.4s
# [CV 7/10] END max_depth=100, max_features=sqrt, n_estimators=10;, score=-1.036 total time=   0.4s
# [CV 8/10] END max_depth=100, max_features=sqrt, n_estimators=10;, score=-0.901 total time=   0.4s
# [CV 9/10] END max_depth=100, max_features=sqrt, n_estimators=10;, score=-0.894 total time=   0.4s
# [CV 10/10] END max_depth=100, max_features=sqrt, n_estimators=10;, score=-0.970 total time=   0.4s
# [CV 1/10] END max_depth=100, max_features=sqrt, n_estimators=50;, score=-0.974 total time=   1.5s
# [CV 2/10] END max_depth=100, max_features=sqrt, n_estimators=50;, score=-0.959 total time=   1.5s
# [CV 3/10] END max_depth=100, max_features=sqrt, n_estimators=50;, score=-0.988 total time=   1.9s
# [CV 4/10] END max_depth=100, max_features=sqrt, n_estimators=50;, score=-0.988 total time=   1.9s
# [CV 5/10] END max_depth=100, max_features=sqrt, n_estimators=50;, score=-0.939 total time=   1.5s
# [CV 6/10] END max_depth=100, max_features=sqrt, n_estimators=50;, score=-1.004 total time=   1.5s
# [CV 7/10] END max_depth=100, max_features=sqrt, n_estimators=50;, score=-1.004 total time=   1.5s
# [CV 8/10] END max_depth=100, max_features=sqrt, n_estimators=50;, score=-0.882 total time=   1.5s
# [CV 9/10] END max_depth=100, max_features=sqrt, n_estimators=50;, score=-0.878 total time=   1.5s
# [CV 10/10] END max_depth=100, max_features=sqrt, n_estimators=50;, score=-0.951 total time=   1.5s
# [CV 1/10] END max_depth=100, max_features=sqrt, n_estimators=100;, score=-0.992 total time=   3.6s
# [CV 2/10] END max_depth=100, max_features=sqrt, n_estimators=100;, score=-0.960 total time=   2.9s
# [CV 3/10] END max_depth=100, max_features=sqrt, n_estimators=100;, score=-0.978 total time=   3.3s
# [CV 4/10] END max_depth=100, max_features=sqrt, n_estimators=100;, score=-0.993 total time=   3.9s
# [CV 5/10] END max_depth=100, max_features=sqrt, n_estimators=100;, score=-0.949 total time=   3.0s
# [CV 6/10] END max_depth=100, max_features=sqrt, n_estimators=100;, score=-0.999 total time=   2.9s
# [CV 7/10] END max_depth=100, max_features=sqrt, n_estimators=100;, score=-1.004 total time=   2.9s
# [CV 8/10] END max_depth=100, max_features=sqrt, n_estimators=100;, score=-0.882 total time=   3.6s
# [CV 9/10] END max_depth=100, max_features=sqrt, n_estimators=100;, score=-0.883 total time=   2.9s
# [CV 10/10] END max_depth=100, max_features=sqrt, n_estimators=100;, score=-0.951 total time=   2.9s
# [CV 1/10] END max_depth=100, max_features=sqrt, n_estimators=500;, score=-0.985 total time=  15.6s
# [CV 2/10] END max_depth=100, max_features=sqrt, n_estimators=500;, score=-0.953 total time=  15.6s
# [CV 3/10] END max_depth=100, max_features=sqrt, n_estimators=500;, score=-0.981 total time=  15.3s
# [CV 4/10] END max_depth=100, max_features=sqrt, n_estimators=500;, score=-0.985 total time=  15.5s
# [CV 5/10] END max_depth=100, max_features=sqrt, n_estimators=500;, score=-0.945 total time=  15.6s
# [CV 6/10] END max_depth=100, max_features=sqrt, n_estimators=500;, score=-0.997 total time=  16.6s
# [CV 7/10] END max_depth=100, max_features=sqrt, n_estimators=500;, score=-1.008 total time=  14.8s
# [CV 8/10] END max_depth=100, max_features=sqrt, n_estimators=500;, score=-0.879 total time=  16.5s
# [CV 9/10] END max_depth=100, max_features=sqrt, n_estimators=500;, score=-0.882 total time=  15.0s
# [CV 10/10] END max_depth=100, max_features=sqrt, n_estimators=500;, score=-0.951 total time=  15.5s
# [CV 1/10] END max_depth=100, max_features=log2, n_estimators=10;, score=-1.003 total time=   0.4s
# [CV 2/10] END max_depth=100, max_features=log2, n_estimators=10;, score=-0.969 total time=   0.4s
# [CV 3/10] END max_depth=100, max_features=log2, n_estimators=10;, score=-0.994 total time=   0.4s
# [CV 4/10] END max_depth=100, max_features=log2, n_estimators=10;, score=-0.974 total time=   0.4s
# [CV 5/10] END max_depth=100, max_features=log2, n_estimators=10;, score=-0.973 total time=   0.4s
# [CV 6/10] END max_depth=100, max_features=log2, n_estimators=10;, score=-1.040 total time=   0.5s
# [CV 7/10] END max_depth=100, max_features=log2, n_estimators=10;, score=-0.985 total time=   0.5s
# [CV 8/10] END max_depth=100, max_features=log2, n_estimators=10;, score=-0.916 total time=   0.5s
# [CV 9/10] END max_depth=100, max_features=log2, n_estimators=10;, score=-0.904 total time=   0.5s
# [CV 10/10] END max_depth=100, max_features=log2, n_estimators=10;, score=-0.950 total time=   0.4s
# [CV 1/10] END max_depth=100, max_features=log2, n_estimators=50;, score=-0.987 total time=   1.5s
# [CV 2/10] END max_depth=100, max_features=log2, n_estimators=50;, score=-0.956 total time=   1.5s
# [CV 3/10] END max_depth=100, max_features=log2, n_estimators=50;, score=-0.990 total time=   1.5s
# [CV 4/10] END max_depth=100, max_features=log2, n_estimators=50;, score=-0.986 total time=   1.4s
# [CV 5/10] END max_depth=100, max_features=log2, n_estimators=50;, score=-0.950 total time=   1.5s
# [CV 6/10] END max_depth=100, max_features=log2, n_estimators=50;, score=-1.002 total time=   1.5s
# [CV 7/10] END max_depth=100, max_features=log2, n_estimators=50;, score=-1.006 total time=   1.9s
# [CV 8/10] END max_depth=100, max_features=log2, n_estimators=50;, score=-0.890 total time=   1.7s
# [CV 9/10] END max_depth=100, max_features=log2, n_estimators=50;, score=-0.886 total time=   1.4s
# [CV 10/10] END max_depth=100, max_features=log2, n_estimators=50;, score=-0.948 total time=   1.5s
# [CV 1/10] END max_depth=100, max_features=log2, n_estimators=100;, score=-0.984 total time=   2.9s
# [CV 2/10] END max_depth=100, max_features=log2, n_estimators=100;, score=-0.964 total time=   3.0s
# [CV 3/10] END max_depth=100, max_features=log2, n_estimators=100;, score=-0.981 total time=   3.7s
# [CV 4/10] END max_depth=100, max_features=log2, n_estimators=100;, score=-0.987 total time=   3.4s
# [CV 5/10] END max_depth=100, max_features=log2, n_estimators=100;, score=-0.945 total time=   2.9s
# [CV 6/10] END max_depth=100, max_features=log2, n_estimators=100;, score=-1.000 total time=   3.4s
# [CV 7/10] END max_depth=100, max_features=log2, n_estimators=100;, score=-1.001 total time=   2.9s
# [CV 8/10] END max_depth=100, max_features=log2, n_estimators=100;, score=-0.882 total time=   2.9s
# [CV 9/10] END max_depth=100, max_features=log2, n_estimators=100;, score=-0.875 total time=   3.0s
# [CV 10/10] END max_depth=100, max_features=log2, n_estimators=100;, score=-0.967 total time=   3.5s
# [CV 1/10] END max_depth=100, max_features=log2, n_estimators=500;, score=-0.983 total time=  15.3s
# [CV 2/10] END max_depth=100, max_features=log2, n_estimators=500;, score=-0.957 total time=  14.6s
# [CV 3/10] END max_depth=100, max_features=log2, n_estimators=500;, score=-0.978 total time=  14.7s
# [CV 4/10] END max_depth=100, max_features=log2, n_estimators=500;, score=-0.987 total time=  17.2s
# [CV 5/10] END max_depth=100, max_features=log2, n_estimators=500;, score=-0.948 total time=  14.7s
# [CV 6/10] END max_depth=100, max_features=log2, n_estimators=500;, score=-0.987 total time=  15.4s
# [CV 7/10] END max_depth=100, max_features=log2, n_estimators=500;, score=-1.004 total time=  15.1s
# [CV 8/10] END max_depth=100, max_features=log2, n_estimators=500;, score=-0.876 total time=  15.0s
# [CV 9/10] END max_depth=100, max_features=log2, n_estimators=500;, score=-0.887 total time=  15.2s
# [CV 10/10] END max_depth=100, max_features=log2, n_estimators=500;, score=-0.950 total time=  14.7s
# Grid Search
# best params:  {'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 500}
#     max_depth max_features  n_estimators      RMSE
# 0          10         sqrt            10  0.983003
# 1          10         sqrt            50  0.976225
# 2          10         sqrt           100  0.974635
# 3          10         sqrt           500  0.972255
# 4          10         log2            10  1.047119
# 5          10         log2            50  1.038649
# 6          10         log2           100  1.038596
# 7          10         log2           500  1.040747
# 8          20         sqrt            10  0.952337
# 9          20         sqrt            50  0.944269
# 10         20         sqrt           100  0.941485
# 11         20         sqrt           500  0.940180
# 12         20         log2            10  0.978690
# 13         20         log2            50  0.965285
# 14         20         log2           100  0.963348
# 15         20         log2           500  0.960760
# 16         50         sqrt            10  0.971359
# 17         50         sqrt            50  0.952752
# 18         50         sqrt           100  0.955639
# 19         50         sqrt           500  0.953377
# 20         50         log2            10  0.964723
# 21         50         log2            50  0.954289
# 22         50         log2           100  0.950412
# 23         50         log2           500  0.951499
# 24        100         sqrt            10  0.970553
# 25        100         sqrt            50  0.956707
# 26        100         sqrt           100  0.958946
# 27        100         sqrt           500  0.956534
# 28        100         log2            10  0.970679
# 29        100         log2            50  0.960137
# 30        100         log2           100  0.958615
# 31        100         log2           500  0.955650
# Test set results:
# RMSE: 0.9635367208666852, Spearman: 0.5856874501607382, MCC: 0.493601453552409

# %%
docking_file = "7rdx_ADP_docking.csv"
activities_file = "activities.csv"
compound_ft_file = "ligands_ecfp4.csv"
target_ft_file = "targets_embedding.csv"
in_ic50 = get_features_df(activities_file, compound_ft_file, target_ft_file).sample(frac=1, random_state=0).reset_index(drop=True)
in_docking = get_docking_features_df(docking_file, compound_ft_file, target_ft_file).sample(frac=1, random_state=0).reset_index(drop=True)

svr_ic50 = SVR(C=10000, gamma=0.05)
svr_docking = SVR(C=10, gamma=0.01)
rf_ic50 = RandomForestRegressor(max_depth=50, max_features='sqrt', n_estimators=10)
rf_docking = RandomForestRegressor(max_depth=20, max_features='sqrt', n_estimators=500)

y = in_ic50['standard_value']
X_train, X_test, y_train_ic50, y_test_ic50 = train_test_split(in_ic50, y, test_size=0.2, random_state=0)
svr_ic50.fit(X_train.iloc[:, 3:], y_train_ic50)
rf_ic50.fit(X_train.iloc[:, 3:], y_train_ic50)
svr_ic50_pred = svr_ic50.predict(X_test.iloc[:, 3:])
rf_ic50_pred = rf_ic50.predict(X_test.iloc[:, 3:])
svr_ic50_errors = abs(svr_ic50_pred-y_test_ic50)
rf_ic50_errors = abs(rf_ic50_pred-y_test_ic50)

y = in_docking['docking score']
X_train, X_test, y_train_docking, y_test_docking = train_test_split(in_docking, y, test_size=0.2, random_state=0)
svr_docking.fit(X_train.iloc[:, 3:], y_train_docking)
rf_docking.fit(X_train.iloc[:, 3:], y_train_docking)
svr_docking_pred = svr_docking.predict(X_test.iloc[:, 3:])
rf_docking_pred = rf_docking.predict(X_test.iloc[:, 3:])
svr_docking_errors = abs(svr_docking_pred-y_test_docking)
rf_docking_errors = abs(rf_docking_pred-y_test_docking)

# %%
import pickle

# save
with open('svr_ic50.pkl','wb') as f:
    pickle.dump(svr_ic50,f)
with open('svr_docking.pkl','wb') as f:
    pickle.dump(svr_docking,f)
with open('rf_ic50.pkl','wb') as f:
    pickle.dump(rf_ic50,f)
with open('rf_docking.pkl','wb') as f:
    pickle.dump(rf_docking,f)

# %%
import seaborn as sns
from matplotlib import pyplot as plt

fig, axes = plt.subplots(1,2,figsize=(8,4))
sns.histplot(svr_ic50_errors, bins=20, ax=axes[0])
sns.histplot(rf_ic50_errors, bins=20, ax=axes[1])
axes[0].set_ylim(0,30)
axes[0].set_xlabel("IC50 value error")
axes[0].set_title("Errors histogram for SVR")
axes[1].set_ylim(0,30)
axes[1].set_title("Errors histogram for RF")
axes[1].set_xlabel("IC50 value error")

fig, axes = plt.subplots(1,2,figsize=(8,4))
sns.histplot(svr_docking_errors, bins=20, ax=axes[0])
sns.histplot(rf_docking_errors, bins=20, ax=axes[1])
axes[0].set_ylim(0,150)
axes[0].set_xlabel("docking score error")
axes[0].set_title("Errors histogram for SVR")
axes[1].set_ylim(0,150)
axes[1].set_title("Errors histogram for RF")
axes[1].set_xlabel("docking score error")
# Out:
# Text(0.5, 0, 'docking score error')

# %%
import score_metrics

mcc_scores = []
mcc_scores.append(score_metrics.mcc(svr_ic50_pred, y_test_ic50.to_numpy(), np.median(y_train_ic50)))
mcc_scores.append(score_metrics.mcc(rf_ic50_pred, y_test_ic50.to_numpy(), np.median(y_train_ic50)))
mcc_scores.append(score_metrics.mcc(svr_docking_pred, y_test_docking.to_numpy(), np.median(y_train_docking)))
mcc_scores.append(score_metrics.mcc(rf_docking_pred, y_test_docking.to_numpy(), np.median(y_train_docking)))

spearman_scores = []
spearman_scores.append(spearman(svr_ic50_pred, y_test_ic50))
spearman_scores.append(spearman(rf_ic50_pred, y_test_ic50))
spearman_scores.append(spearman(svr_docking_pred, y_test_docking))
spearman_scores.append(spearman(rf_docking_pred, y_test_docking))

rmse_scores = []
rmse_scores.append(rmse(svr_ic50_pred, y_test_ic50))
rmse_scores.append(rmse(rf_ic50_pred, y_test_ic50))
rmse_scores.append(rmse(svr_docking_pred, y_test_docking))
rmse_scores.append(rmse(rf_docking_pred, y_test_docking))

fig, axes = plt.subplots(2,1,figsize=(5,8))
axes[0].bar(['SVR IC50', 'RF IC50', 'SVR docking', 'RF docking'], mcc_scores)
axes[1].bar(['SVR IC50', 'RF IC50', 'SVR docking', 'RF docking'], spearman_scores)
axes[0].set_title("MCC")
axes[1].set_title("Spearman")

fig, axes = plt.subplots(1,2,figsize=(7,3))
axes[0].bar(['SVR', 'RF'], rmse_scores[:2])
axes[1].bar(['SVR', 'RF'], rmse_scores[2:])
axes[0].set_title("RMSE for IC50")
axes[1].set_title("RMSE for docking")
# Out:
# Text(0.5, 1.0, 'RMSE for docking')
