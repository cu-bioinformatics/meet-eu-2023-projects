# %%
import pandas as pd

# %% [markdown]
# Many targets have id CHEMBL612545, which in ChEMBL is an unchecked protein and does not have a sequence. Values from `activities.csv` need to be extracted and sorted in such a way, that manual searching for those sequences is possibly comfortable.

# %%
df = pd.read_csv('/content/actvities.csv')
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'action_type', 'activity_comment', 'activity_id',
#        'activity_properties', 'assay_chembl_id', 'assay_description',
#        'assay_type', 'assay_variant_accession', 'assay_variant_mutation',
#        'bao_endpoint', 'bao_format', 'bao_label', 'canonical_smiles',
#        'data_validity_comment', 'data_validity_description',
#        'document_chembl_id', 'document_journal', 'document_year',
#        'ligand_efficiency', 'molecule_chembl_id', 'molecule_pref_name',
#        'parent_molecule_chembl_id', 'pchembl_value', 'potential_duplicate',
#        'qudt_units', 'record_id', 'relation', 'src_id', 'standard_flag',
#        'standard_relation', 'standard_text_value', 'standard_type',
#        'standard_units', 'standard_upper_value', 'standard_value',
#        'target_chembl_id', 'target_organism', 'target_pref_name',
#        'target_tax_id', 'text_value', 'toid', 'type', 'units', 'uo_units',
#        'upper_value', 'value'],
#       dtype='object')

# %%
assay_id_counts = df['assay_chembl_id'].value_counts()

# %%
assay_id_counts
# Out:
# CHEMBL1614220    125
# CHEMBL2060535     62
# CHEMBL2060534     62
# CHEMBL2060537     62
# CHEMBL4042368     60
#                 ...
# CHEMBL2043712      1
# CHEMBL2043705      1
# CHEMBL2043706      1
# CHEMBL1944232      1
# CHEMBL3094684      1
# Name: assay_chembl_id, Length: 152, dtype: int64

# %%
i=0
n=0
for el in assay_id_counts:
    if el>2:
        i+=el
        n+=1
print(f'To get IC50 for this many target-ligand pairs:{i} we have to manualy set sequence for this many proteins: {n}, which means checking {n} papers')
# print(n)
# Out:
# To get IC50 for this many target-ligand pairs:929 we have to manualy set sequence for this many proteins: 67, which means checking 67 papers

# %%
df['target_chembl_id'].value_counts()
# Out:
# CHEMBL612545     760
# CHEMBL1293269    157
# CHEMBL5118        38
# CHEMBL4523163     35
# CHEMBL4380        32
# CHEMBL4523582      7
# CHEMBL5980         4
# CHEMBL345          3
# CHEMBL4953         1
# CHEMBL379          1
# Name: target_chembl_id, dtype: int64

# %%
unique_assays = df[['assay_chembl_id','assay_description','document_chembl_id','target_chembl_id']].rename(columns={'assay_chembl_id':'assay_id'}).drop_duplicates().set_index('assay_id')

# %%
unique_assays
# Out:
#                                                assay_description  \
# assay_id
# CHEMBL857450   Inhibition against DNA-Dependent ATPase activi...
# CHEMBL689340   Inhibition against DNA-Dependent GTPase activi...
# CHEMBL689341   Inhibition against the primase activity of HSV...
# CHEMBL690907   Inhibition against Primase by coupled primase-...
# CHEMBL695117   Inhibitory concentration against herpes simple...
# ...                                                          ...
# CHEMBL5098106  Inhibition of Hepatitis C virus NS3 helicase m...
# CHEMBL5135910  Inhibition of SARS-CoV-2 nsp13 helicase-associ...
# CHEMBL5135911  Inhibition of SARS-CoV-2 nsp13 helicase-associ...
# CHEMBL5138458  Inhibition of Cy5-dT15 ssDNA to Hepatitis C vi...
# CHEMBL5138459  Inhibition of Hepatitis C virus NS3 helicase m...
#
#               document_chembl_id target_chembl_id
# assay_id
# CHEMBL857450       CHEMBL1128737       CHEMBL4380
# CHEMBL689340       CHEMBL1128737       CHEMBL4380
# CHEMBL689341       CHEMBL1128737       CHEMBL4380
# CHEMBL690907       CHEMBL1128737       CHEMBL4380
# CHEMBL695117       CHEMBL1139458       CHEMBL4380
# ...                          ...              ...
# CHEMBL5098106      CHEMBL5096190     CHEMBL612545
# CHEMBL4014234  Inhibition of 5-FAM peptide binding to Hepatit...
# CHEMBL4373305  Inhibition of recombinant full length HCV geno...
# CHEMBL970622   Inhibition of ATPase activity of HCV NS3/4A he...
# CHEMBL970623     Inhibition of HCV NS3/4A helicase by FRET assay
#
#               document_chembl_id target_chembl_id  n_compounds
# assay_id
# CHEMBL1614220      CHEMBL1201862    CHEMBL1293269          125
# CHEMBL2060535      CHEMBL2057104     CHEMBL612545           62
# CHEMBL2060534      CHEMBL2057104     CHEMBL612545           62
# CHEMBL2060537      CHEMBL2057104     CHEMBL612545           62
# CHEMBL4042368      CHEMBL4041513     CHEMBL612545           60
# CHEMBL3870401      CHEMBL3870302     CHEMBL612545           43
# CHEMBL4428655      CHEMBL4428043    CHEMBL4523163           35
# CHEMBL4428657      CHEMBL4428043     CHEMBL612545           34
# CHEMBL3122911      CHEMBL3120058     CHEMBL612545           18
# CHEMBL1816593      CHEMBL1811822     CHEMBL612545           16
# CHEMBL1772276      CHEMBL1770144     CHEMBL612545           14
# CHEMBL832708       CHEMBL1145280    CHEMBL1293269           13
# CHEMBL996802       CHEMBL1152218     CHEMBL612545           13
# CHEMBL857450       CHEMBL1128737       CHEMBL4380           13
# CHEMBL695718       CHEMBL1134109    CHEMBL1293269           12
# CHEMBL4004009      CHEMBL4002613     CHEMBL612545           12
# CHEMBL1252592      CHEMBL1250429     CHEMBL612545           11
# CHEMBL1057306      CHEMBL1153502       CHEMBL5118           11
# CHEMBL1055727      CHEMBL1153502       CHEMBL5118           11
# CHEMBL1912635      CHEMBL1909523     CHEMBL612545           10
# CHEMBL1912633      CHEMBL1909523     CHEMBL612545           10
# CHEMBL3870404      CHEMBL3870302     CHEMBL612545           10
# CHEMBL3870403      CHEMBL3870302     CHEMBL612545           10
# CHEMBL3870402      CHEMBL3870302     CHEMBL612545           10
# CHEMBL1827371      CHEMBL1821570     CHEMBL612545            9
# CHEMBL1827370      CHEMBL1821570     CHEMBL612545            9
# CHEMBL3119165      CHEMBL3112456     CHEMBL612545            9
# CHEMBL3119166      CHEMBL3112456     CHEMBL612545            9
# CHEMBL1826761      CHEMBL1821570     CHEMBL612545            9
# CHEMBL964113       CHEMBL1153308       CHEMBL5118            8
# CHEMBL964112       CHEMBL1153308       CHEMBL5118            8
# CHEMBL689340       CHEMBL1128737       CHEMBL4380            8
# CHEMBL689341       CHEMBL1128737       CHEMBL4380            8
# CHEMBL1827375      CHEMBL1821570     CHEMBL612545            7
# CHEMBL3106651      CHEMBL3102775     CHEMBL612545            7
# CHEMBL1827374      CHEMBL1821570     CHEMBL612545            7
# CHEMBL1827376      CHEMBL1821570     CHEMBL612545            7
# CHEMBL2013323      CHEMBL2010683     CHEMBL612545            7
# CHEMBL3106647      CHEMBL3102775     CHEMBL612545            7
# CHEMBL3106648      CHEMBL3102775     CHEMBL612545            7
# CHEMBL1827372      CHEMBL1821570     CHEMBL612545            7
# CHEMBL3106650      CHEMBL3102775     CHEMBL612545            7
# CHEMBL3106649      CHEMBL3102775     CHEMBL612545            7
# CHEMBL1827373      CHEMBL1821570     CHEMBL612545            7
# CHEMBL970624       CHEMBL1138524     CHEMBL612545            6
# CHEMBL4014234      CHEMBL4011661     CHEMBL612545            6
# CHEMBL4373305      CHEMBL4371078     CHEMBL612545            6
# CHEMBL970622       CHEMBL1138524     CHEMBL612545            6
# CHEMBL970623       CHEMBL1138524     CHEMBL612545            6

# %%
unique_assays[unique_assays.n_compounds>5]['n_compounds'].sum()
# Out:
# 861

# %%
unique_assays.to_csv('assays_targets.csv')
