# %%
import pandas as pd

# %%
df = pd.read_csv('updated_repurposing_result.csv')

# %%
for i in df['ligandID']=='NaN': print (i)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(df)
# Out:
#          proteinID                            ligandID       mean  median  \
# 0    7RDY-no-extra                Mrv1909-10091921542D -17.747059  -17.70
# 1    7RDY-no-extra                Mrv0541-02231214492D -15.847727  -15.85
# 2        7RDY-zinc                Mrv1909-08181923252D -15.500000  -15.50
# 3    7RDY-no-extra                Mrv0541-02231215192D -14.802273  -14.70
# 4    7RDY-no-extra                Mrv0541-02231215202D -14.772727  -14.75
# 5        7RDY-zinc  Mrv1909-12152018162D-1704021550240 -14.770455  -14.75
# 6    7RDY-no-extra                Mrv1909-11222222552D -14.552273  -14.60
# 7    7RDY-no-extra                Mrv1909-11142221202D -14.506818  -14.70
# 8        7RDY-zinc  Mrv0541-04191212162D-1704021536512 -14.477273  -14.50
# 9        7RDY-zinc                Mrv1909-03042003442D -14.445455  -14.40
# 10   7RDY-no-extra           Glycyrrhetinic-acid-ChEBI -14.445455  -14.45
# 11   7RDY-no-extra  Mrv1652306131722002D-1704021541914 -14.434091  -14.40
# ...

# %%
df2 = pd.read_csv('grouped_data.csv')

# %%
display(df2)
# Out:
#            proteinID                            ligandID       mean  median  \
# 0      7RDY-no-extra                Mrv1909-05092102032D   0.000000    0.00
# 1          7RDY-zinc                Mrv1718006281815442D  -0.750000   -0.75
# 2      7RDY-no-extra                Mrv1718007121817592D  -0.750000   -0.75
# 3      7RDY-no-extra                Mrv0541-02241215252D  -0.750000   -0.75
# 4      7RDY-no-extra                Mrv1909-12102019322D  -0.900000   -0.90
# ...              ...                                 ...        ...     ...
# 10556      7RDY-zinc  Mrv0541-02231215132D-1704021536550 -15.481818  -15.80
# 10557      7RDY-zinc                Mrv1909-08181923252D -15.500000  -15.50
# 10558  7RDY-no-extra                Mrv1718006171818092D -15.581818  -16.10
# 10559  7RDY-no-extra                Mrv0541-02231214492D -15.847727  -15.85
# 10560  7RDY-no-extra                Mrv1909-10091921542D -17.747059  -17.70
#
#         max   min       var
# ...

# %%
for i in range(len(df2['ligandID'])): 
    if df2['ligandID'][i] == 'output.pdbqt': 
        print(i)
# Out:
# 10532

# %%
df2['ligandID'][10532]
# Out:
# 'output.pdbqt'

# %%
df2.drop(10532, inplace = True)

# %%
udf2=df2.reset_index()

# %%
for i in range(len(udf2['ligandID'])): 
    if udf2['ligandID'][i] == 'output.pdbqt': 
        print(i)

# %%
udf2.to_csv('updated_grouped_data.csv', index = False)
